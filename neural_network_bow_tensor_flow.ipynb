# %%
# Core python libraries
import csv
import re
import math
import os
import time

# External libraries.
import nltk
import numpy
import pandas
import scipy
import sklearn
import tempfile

# Tensorflow and related.
import tensorflow as tf

# Plotting
import matplotlib.pyplot as plt

# For dynamically reolading modules. imp.reload(module_name) 
import imp

# Internal libraries
import tf_utils

# So you know when this code block finishes.
print ("Done")
# Out:
# Done

# %%
#TODO(Max): make a library that does all this preprocessing
data = pandas.read_csv("data/train.csv") # Can read a subset. First nrows of the total.
LABEL_COLUMN = "SalaryNormalized"

TEST_SIZE = .3


print(len(data))
# Out:
# 171482

# %%
# sklearn.cross_validation has been replaced with model_selection.
X_train_index, X_test_index, Y_train, Y_test = sklearn.model_selection.train_test_split(
    data.index, data[LABEL_COLUMN], test_size=TEST_SIZE, random_state=42)

# Keep train and test as pandas dataframes.
X_train = data.iloc[X_train_index]
X_test = data.iloc[X_test_index]

y_train = numpy.array(X_train[LABEL_COLUMN].astype(numpy.float32))
y_test = numpy.array(X_test[LABEL_COLUMN].astype(numpy.float32))

print ("Done")
# Out:
# Done

# %%
# Normalizing input values to mean 0, standard deviation 1.
train_mean, train_std = y_train.mean(), y_train.std()

# Normalize input labels and expectations
y_train = tf_utils.normalize_input(y_train, train_mean, train_std)
y_test = tf_utils.normalize_input(y_test, train_mean, train_std)

# %%
target_column = "CompleteJobListingStemmed"

x_train_text = X_train[target_column]
x_test_text = X_test[target_column]

# %%
min_word_frequency = 59

sklearn_bow = True # Otherwise we use Tensorflow BOW.

if sklearn_bow:
    # Gives 7600 unique words with min frequency 75 and stopwords removed.
    # 7797 if we leave stopwords in.

    count_vect = sklearn.feature_extraction.text.CountVectorizer(
        min_df=min_word_frequency, decode_error='ignore')

    # Transform BOW test set.
    x_train = count_vect.fit_transform(x_train_text)
    x_test = count_vect.transform(x_test_text)
    n_words = x_train.shape[1]
    max_document_length = n_words

else:
    # Look here for a tutorial https://medium.com/@ilblackdragon/tensorflow-text-classification-615198df9231
    # Gives 8712 unique words with min word frequency of 75
    vocab_processor = tf.contrib.learn.preprocessing.VocabularyProcessor(
        max_document_length, min_frequency=min_word_frequency)
    x_train = numpy.array(list(vocab_processor.fit_transform(x_train_text)))
    x_test = numpy.array(list(vocab_processor.transform(x_test_text)))
    n_words = len(vocab_processor.vocabulary_)
    max_document_length = max([len(x.split(" ")) for x in x_train_text])
    
print("x_train shape: %s, %s" % x_train.shape)
print("x_test shape: %s, %s" % x_test.shape)
print("Total distinct words: %d" % n_words)
print("Number of training rows: %d" % x_train.shape[0])
# Out:
# x_train shape: 120037, 8762
# x_test shape: 51445, 8762
# Total distinct words: 8762
# Number of training rows: 120037

# %%
# Define data nput functions. These have to be done here as the 
# functions take no arguments. Also the dict labels are specific to 
# the model.
max_document_length = n_words

def input_fn():
    for batch_input, batch_labels in tf_utils.generate_batch(
        batch_size, number_of_batches, max_document_length,
                                                    x_train, y_train):
        yield {input_data: batch_input, input_target: batch_labels}

def eval_input_fn():
    for batch_input, batch_labels in tf_utils.generate_batch(
        batch_size, number_of_validation_batches, max_document_length,
                                                    x_test, y_test):
        yield {input_data: batch_input, input_target: batch_labels}

# %%
# Define model

graph = tf.Graph()

sess = tf.Session(graph=graph)

learning_rate = .01

l1_regularization_coef = 0.0 #1
l2_regularization_coef = 0.0 #1

# Implement this by batch.
batch_size = 2048

#(32,16,8) worked well
# (1024, 256, 64) Doesn't work
# (128, 32, 8) Neither
FIRST_LAYER_SIZE = 32
SECOND_LAYER_SIZE = 16
THIRD_LAYER_SIZE = 8

# Given small layers probably need this a little higher.
DROPOUT_KEEP_PROBABILITY = 0.8

with graph.as_default():

    with tf.name_scope("input_data"):
        # Initialize data placeholders
        input_data = tf.placeholder(shape=[batch_size, max_document_length], dtype=tf.float32)
        input_target = tf.placeholder(shape=[batch_size, 1], dtype=tf.float32, name="labels")

    with tf.device('/gpu:0'):

        with tf.name_scope("first_hidden_layer"):
            first_layer_hidden_units = tf.Variable(tf.truncated_normal(shape=[n_words, FIRST_LAYER_SIZE], stddev=.5))
            first_layer_bias = tf.Variable(tf.truncated_normal(shape=[1], stddev=.5))
            first_layer_product = tf.matmul(input_data, first_layer_hidden_units)
            first_layer_output = tf.contrib.layers.dropout(
                tf.nn.relu(tf.add(first_layer_product, first_layer_bias)), DROPOUT_KEEP_PROBABILITY)
            
        with tf.name_scope("second_hidden_layer"):
            second_layer_hidden_units = tf.Variable(tf.truncated_normal(shape=[FIRST_LAYER_SIZE, SECOND_LAYER_SIZE], stddev=.5))
            second_layer_bias = tf.Variable(tf.truncated_normal(shape=[1], stddev=.5))
            second_layer_product = tf.matmul(first_layer_output, second_layer_hidden_units)
            second_layer_output = tf.contrib.layers.dropout(
                tf.nn.relu(tf.add(second_layer_product, second_layer_bias)), DROPOUT_PROPORTION)
            
        with tf.name_scope("third_hidden_layer"):
            third_layer_hidden_units = tf.Variable(tf.truncated_normal(shape=[SECOND_LAYER_SIZE, THIRD_LAYER_SIZE], stddev=.5))
            third_layer_bias = tf.Variable(tf.truncated_normal(shape=[1], stddev=.5))
            third_layer_product = tf.matmul(second_layer_output, third_layer_hidden_units)
            third_layer_output = tf.contrib.layers.dropout(
                tf.nn.relu(tf.add(third_layer_product, third_layer_bias)), DROPOUT_KEEP_PROBABILITY)

        with tf.name_scope("output_layer"):
            output_layer_coefficients = tf.Variable(tf.truncated_normal(shape=[THIRD_LAYER_SIZE, 1], stddev=.5))
            output_layer_bias = tf.Variable(tf.truncated_normal(shape=[1], stddev=.5))
            output_layer_product = tf.matmul(third_layer_output, output_layer_coefficients)
            model_output = tf.add(output_layer_product, output_layer_bias, name="predictions")

    with tf.name_scope("loss"):
        # Mean Absolute Error.
        loss = tf.reduce_mean(tf.abs(tf.subtract(input_target, model_output)))

        # If we are using regularization.
        if l1_regularization_coef > 0 or l2_regularization_coef > 0:
            l1_regularizer = tf.contrib.layers.l1_regularizer(scale=l1_regularization_coef)
            l2_regularizer = tf.contrib.layers.l2_regularizer(scale=l2_regularization_coef)

            weights = tf.trainable_variables() # all vars of your graph
            regularization_penalty = tf.add(tf.contrib.layers.apply_regularization(l1_regularizer, weights),
                                             tf.contrib.layers.apply_regularization(l2_regularizer, weights))
            loss = loss + regularization_penalty # this loss needs to be minimized

    with tf.name_scope("reporting"):
        # Converts back to original, salary scale.
        error_salary_scale = tf.multiply(tf.subtract(input_target, model_output), train_std)

        mean_absolute_error_salary_scale = tf.reduce_mean(
            tf.abs(error_salary_scale))

        # Log for tensorboard
        training_summary = tf.summary.scalar('train_loss', loss)
        validation_summary = tf.summary.scalar('validation_loss', loss)
        # Add mean absolute errors.
        training_mae = tf.summary.scalar('train_mae', mean_absolute_error_salary_scale)
        validation_mae = tf.summary.scalar('validation_mae', mean_absolute_error_salary_scale)

    global_step = tf.Variable(0, name='global_step', trainable=False)

    # Declare optimizer
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)

    # This one seems to work better :D
    train_op = tf.contrib.layers.optimize_loss(      
     loss, tf.contrib.framework.get_global_step(),      
     optimizer='Adam'
        , learning_rate=learning_rate)

# %%
# Number of
number_of_epochs = 100
batches_per_epoch = len(x_train_text)/batch_size
number_of_batches = math.ceil(len(x_train_text)/batch_size)
number_of_validation_batches = number_of_batches

logs_dir = "logs/neuralnetbagofwords"

checkpoint_frequency = 250

reporting_frequency = 3

total_loss = 0
validation_loss = 0
validation_batch_average_window = 100

ckpt = None
ckpt = tf.train.get_checkpoint_state(logs_dir)

# %%
# TF Queue Logic
"""
QUEUE_LIMIT = 500000

# Try me out
#batch_size = 256


with graph.as_default():
    queue = tf.RandomShuffleQueue(
        capacity=QUEUE_LIMIT, min_after_dequeue=batch_size,
        dtypes=[tf.float32, tf.float32],
        shapes = [(n_words,), (1,)],
        seed=1999)

    with tf.name_scope("preprocess_data"):
        with tf.device('/cpu:0'):

            # Initialize data placeholders
            x_data = tf.placeholder(shape=[batch_size, max_document_length], dtype=tf.int32)
            y_target = tf.placeholder(shape=[batch_size, 1], dtype=tf.float32, name="labels")
            #with tf.device('/cpu:0'):
            identity_mat = tf.diag(tf.ones(shape=[vocab_size]))
            # This is also an embedding_lookup_sparse function that would create a sparse tensor.
            x_embed = tf.nn.embedding_lookup(identity_mat, x_data)
            # Collapse across the document length dimension. Leaving only the number of tokens.
            example = tf.reduce_sum(x_embed, 1)

            enqueue_op = queue.enqueue_many((example, y_target))

        # Dequeue our data. Use dequeue_many(batch_size) later.
        dequeue_op = queue.dequeue_many(batch_size)

# Create 8 threads.
#qr = tf.train.QueueRunner(queue, [enqueue_op] * 8)
# Launch the graph.
with tf.Session(graph=graph) as session:
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)


#sess = tf.Session()
    #enqueue_threads = qr.create_threads(sess, coord=coord, start=True)
    for step in range(10): # do to 100 iterations
        #if coord.should_stop():
        #    break
        #print(feed_dict)
        start_time = time.time()
        feed_dict = input_fn()
        #print(feed_dict)
        thing = session.run([enqueue_op], feed_dict=next(feed_dict))
        duration = time.time() - start_time
        print("Batch %s Enqueue Duration: %.4f" % (step +1, duration))
    coord.request_stop()
    coord.join(threads)
"""
# Out:
# <generator object input_fn at 0x7f4a9ca09a98>
# Batch 1 Enqueue Duration: 7.1514
# <generator object input_fn at 0x7f4a9e63a5c8>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-eace65db0800> in <module>()
#      47         feed_dict = input_fn()
#      48         print(feed_dict)
# ---> 49         thing = session.run([enqueue_op], feed_dict=next(feed_dict))
#      50         duration = time.time() - start_time
#      51         print("Batch %s Enqueue Duration: %.4f" % (step +1, duration))
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
with tf.Session(graph=graph) as session:
    #enqueue_threads = qr.create_threads(sess, coord=coord, start=True)
    for step in range(10): # do to 100 iterations
        #if coord.should_stop():
        #    break
        #print(feed_dict)
        data, label = session.run([dequeue_op])
        print(data)
        print(label)

# %%
# Where to save this model.
model_path = os.path.join(logs_dir, time.strftime("%Y-%m-%d-%H-%M-%S"))

if ckpt:
    restore_from_model = True
    print("Restore from model!")
else:
    restore_from_model = False

with tf.Session(graph=graph, config=tf.ConfigProto(
    allow_soft_placement=True, log_device_placement=True)) as session:
    summaries = tf.summary.merge_all()                                                       
    writer = tf.summary.FileWriter(model_path,
        graph=session.graph)                  

    saver = tf.train.Saver(tf.global_variables()) 
                                                                                                  
    session.run(tf.global_variables_initializer())
    
    
    if restore_from_model:
        saver.restore(session, ckpt.model_checkpoint_path)
        
    global_step = 0
        
    for epoch in range(number_of_epochs):
        eval_feed_generator = eval_input_fn()
        # Shuffle the training input
        x_train, y_train = tf_utils.unison_shuffled_copies(x_train, y_train)

        for step, feed_dict in enumerate(input_fn()):
            global_step += 1
            start_time = time.time()

            _, temp_loss = session.run([train_op, loss], feed_dict=feed_dict)
            
            duration = time.time() - start_time
            
            if global_step % reporting_frequency == 0:
                print("Epoch: %s Iteration: %s : Loss: %.4f (%.3f sec)" % 
                      (epoch, (step + 1), temp_loss, duration))

                train_summ, train_mae = session.run([training_summary, training_mae], feed_dict=feed_dict)
                writer.add_summary(train_summ, global_step)
                writer.add_summary(train_mae, global_step)
                _, valid_summ, valid_mae = session.run(
                        [loss, validation_summary, validation_mae],
                        feed_dict=next(eval_feed_generator))
                writer.add_summary(valid_summ, global_step)
                writer.add_summary(valid_mae, global_step)

                writer.flush()                

            if (global_step % checkpoint_frequency == 0) or (global_step == number_of_batches):
                print("Saving at epoch %s step: %s" % (epoch, step + 1))
                saver.save(session, model_path, global_step=tf.contrib.framework.get_global_step())
# Out:
# Restore from model!
# INFO:tensorflow:Restoring parameters from logs/neuralnetbagofwords/2017-06-28-22-26-46-2750
# Epoch: 0 Iteration: 3 : Loss: 0.2844 (0.037 sec)
# Epoch: 0 Iteration: 6 : Loss: 0.3009 (0.037 sec)
# Epoch: 0 Iteration: 9 : Loss: 0.3248 (0.039 sec)
# Epoch: 0 Iteration: 12 : Loss: 0.3093 (0.036 sec)
# Epoch: 0 Iteration: 15 : Loss: 0.2976 (0.037 sec)
# Epoch: 0 Iteration: 18 : Loss: 0.3163 (0.053 sec)
# Epoch: 0 Iteration: 21 : Loss: 0.3038 (0.060 sec)
# Epoch: 0 Iteration: 24 : Loss: 0.3006 (0.057 sec)
# Epoch: 0 Iteration: 27 : Loss: 0.3088 (0.053 sec)
# Epoch: 0 Iteration: 30 : Loss: 0.3207 (0.042 sec)
# Epoch: 0 Iteration: 33 : Loss: 0.3026 (0.049 sec)
# Epoch: 0 Iteration: 36 : Loss: 0.3168 (0.038 sec)
# Epoch: 0 Iteration: 39 : Loss: 0.3106 (0.037 sec)
# Epoch: 0 Iteration: 42 : Loss: 0.2969 (0.037 sec)
# Epoch: 0 Iteration: 45 : Loss: 0.3020 (0.036 sec)
# Epoch: 0 Iteration: 48 : Loss: 0.3078 (0.049 sec)
# Epoch: 0 Iteration: 51 : Loss: 0.3182 (0.047 sec)
# Epoch: 0 Iteration: 54 : Loss: 0.3048 (0.054 sec)
# Epoch: 0 Iteration: 57 : Loss: 0.3034 (0.038 sec)
# Saving at epoch 0 step: 59
# Epoch: 1 Iteration: 1 : Loss: 0.3107 (0.038 sec)
# Epoch: 1 Iteration: 4 : Loss: 0.3114 (0.038 sec)
# Epoch: 1 Iteration: 7 : Loss: 0.2994 (0.038 sec)
# Epoch: 1 Iteration: 10 : Loss: 0.2991 (0.038 sec)
# Epoch: 1 Iteration: 13 : Loss: 0.3044 (0.037 sec)
# Epoch: 1 Iteration: 16 : Loss: 0.3093 (0.038 sec)
# Epoch: 1 Iteration: 19 : Loss: 0.2860 (0.046 sec)
# Epoch: 1 Iteration: 22 : Loss: 0.2926 (0.046 sec)
# Epoch: 1 Iteration: 25 : Loss: 0.3037 (0.047 sec)
# Epoch: 1 Iteration: 28 : Loss: 0.3198 (0.048 sec)
# Epoch: 1 Iteration: 31 : Loss: 0.3119 (0.049 sec)
# Epoch: 1 Iteration: 34 : Loss: 0.3123 (0.045 sec)
# Epoch: 1 Iteration: 37 : Loss: 0.3110 (0.047 sec)
# Epoch: 1 Iteration: 40 : Loss: 0.2996 (0.047 sec)
# Epoch: 1 Iteration: 43 : Loss: 0.2866 (0.047 sec)
# Epoch: 1 Iteration: 46 : Loss: 0.2918 (0.047 sec)
# Epoch: 1 Iteration: 49 : Loss: 0.3052 (0.035 sec)
# Epoch: 1 Iteration: 52 : Loss: 0.3149 (0.035 sec)
# Epoch: 1 Iteration: 55 : Loss: 0.3150 (0.035 sec)
# Epoch: 1 Iteration: 58 : Loss: 0.2924 (0.034 sec)
# Epoch: 2 Iteration: 2 : Loss: 0.2965 (0.035 sec)
# Epoch: 2 Iteration: 5 : Loss: 0.2940 (0.036 sec)
# Epoch: 2 Iteration: 8 : Loss: 0.3258 (0.035 sec)
# Epoch: 2 Iteration: 11 : Loss: 0.3171 (0.035 sec)
# Epoch: 2 Iteration: 14 : Loss: 0.3159 (0.035 sec)
# Epoch: 2 Iteration: 17 : Loss: 0.3119 (0.036 sec)
# Epoch: 2 Iteration: 20 : Loss: 0.3023 (0.035 sec)
# Epoch: 2 Iteration: 23 : Loss: 0.2983 (0.036 sec)
# Epoch: 2 Iteration: 26 : Loss: 0.3115 (0.035 sec)
# Epoch: 2 Iteration: 29 : Loss: 0.3001 (0.035 sec)
# Epoch: 2 Iteration: 32 : Loss: 0.2981 (0.036 sec)
# Epoch: 2 Iteration: 35 : Loss: 0.3092 (0.036 sec)
# Epoch: 2 Iteration: 38 : Loss: 0.3001 (0.035 sec)
# Epoch: 2 Iteration: 41 : Loss: 0.3123 (0.035 sec)
# Epoch: 2 Iteration: 44 : Loss: 0.3046 (0.034 sec)
# Epoch: 2 Iteration: 47 : Loss: 0.3037 (0.036 sec)
# Epoch: 2 Iteration: 50 : Loss: 0.2966 (0.035 sec)
# Epoch: 2 Iteration: 53 : Loss: 0.3061 (0.036 sec)
# Epoch: 2 Iteration: 56 : Loss: 0.3061 (0.035 sec)
# Epoch: 2 Iteration: 59 : Loss: 0.3099 (0.036 sec)
# Epoch: 3 Iteration: 3 : Loss: 0.2855 (0.035 sec)
# Epoch: 3 Iteration: 6 : Loss: 0.2992 (0.044 sec)
# Epoch: 3 Iteration: 9 : Loss: 0.3064 (0.035 sec)
# Epoch: 3 Iteration: 12 : Loss: 0.3042 (0.035 sec)
# Epoch: 3 Iteration: 15 : Loss: 0.3159 (0.036 sec)
# Epoch: 3 Iteration: 18 : Loss: 0.2921 (0.036 sec)
# Epoch: 3 Iteration: 21 : Loss: 0.3000 (0.036 sec)
# Epoch: 3 Iteration: 24 : Loss: 0.3035 (0.036 sec)
# Epoch: 3 Iteration: 27 : Loss: 0.3142 (0.036 sec)
# Epoch: 3 Iteration: 30 : Loss: 0.2995 (0.036 sec)
# Epoch: 3 Iteration: 33 : Loss: 0.2951 (0.036 sec)
# Epoch: 3 Iteration: 36 : Loss: 0.3151 (0.036 sec)
# Epoch: 3 Iteration: 39 : Loss: 0.2959 (0.035 sec)
# Epoch: 3 Iteration: 42 : Loss: 0.2962 (0.036 sec)
# Epoch: 3 Iteration: 45 : Loss: 0.3347 (0.041 sec)
# Epoch: 3 Iteration: 48 : Loss: 0.3072 (0.038 sec)
# Epoch: 3 Iteration: 51 : Loss: 0.3113 (0.037 sec)
# Epoch: 3 Iteration: 54 : Loss: 0.3218 (0.036 sec)
# Epoch: 3 Iteration: 57 : Loss: 0.3142 (0.037 sec)
# Epoch: 4 Iteration: 1 : Loss: 0.2914 (0.036 sec)
# Epoch: 4 Iteration: 4 : Loss: 0.2917 (0.036 sec)
# Epoch: 4 Iteration: 7 : Loss: 0.3043 (0.036 sec)
# Epoch: 4 Iteration: 10 : Loss: 0.3141 (0.036 sec)
# Epoch: 4 Iteration: 13 : Loss: 0.3145 (0.036 sec)
# Saving at epoch 4 step: 14
# Epoch: 4 Iteration: 16 : Loss: 0.3007 (0.036 sec)
# Epoch: 4 Iteration: 19 : Loss: 0.3031 (0.036 sec)
# Epoch: 4 Iteration: 22 : Loss: 0.3076 (0.036 sec)
# Epoch: 4 Iteration: 25 : Loss: 0.3255 (0.036 sec)
# Epoch: 4 Iteration: 28 : Loss: 0.2843 (0.036 sec)
# Epoch: 4 Iteration: 31 : Loss: 0.3125 (0.040 sec)
# Epoch: 4 Iteration: 34 : Loss: 0.3049 (0.036 sec)
# Epoch: 4 Iteration: 37 : Loss: 0.3100 (0.036 sec)
# Epoch: 4 Iteration: 40 : Loss: 0.3105 (0.035 sec)
# Epoch: 4 Iteration: 43 : Loss: 0.3084 (0.036 sec)
# Epoch: 4 Iteration: 46 : Loss: 0.3289 (0.036 sec)
# Epoch: 4 Iteration: 49 : Loss: 0.3135 (0.036 sec)
# Epoch: 4 Iteration: 52 : Loss: 0.3141 (0.037 sec)
# Epoch: 4 Iteration: 55 : Loss: 0.2868 (0.036 sec)
# Epoch: 4 Iteration: 58 : Loss: 0.3038 (0.036 sec)
# Epoch: 5 Iteration: 2 : Loss: 0.2961 (0.036 sec)
# Epoch: 5 Iteration: 5 : Loss: 0.3016 (0.040 sec)
# Epoch: 5 Iteration: 8 : Loss: 0.3030 (0.036 sec)
# Epoch: 5 Iteration: 11 : Loss: 0.2956 (0.036 sec)
# Epoch: 5 Iteration: 14 : Loss: 0.3062 (0.036 sec)
# Epoch: 5 Iteration: 17 : Loss: 0.3017 (0.036 sec)
# Epoch: 5 Iteration: 20 : Loss: 0.2961 (0.036 sec)
# Epoch: 5 Iteration: 23 : Loss: 0.2885 (0.036 sec)
# Epoch: 5 Iteration: 26 : Loss: 0.2928 (0.036 sec)
# Epoch: 5 Iteration: 29 : Loss: 0.3045 (0.036 sec)
# Epoch: 5 Iteration: 32 : Loss: 0.3070 (0.036 sec)
# Epoch: 5 Iteration: 35 : Loss: 0.3060 (0.036 sec)
# Epoch: 5 Iteration: 38 : Loss: 0.3100 (0.037 sec)
# Epoch: 5 Iteration: 41 : Loss: 0.2944 (0.036 sec)
# Epoch: 5 Iteration: 44 : Loss: 0.2977 (0.035 sec)
# Epoch: 5 Iteration: 47 : Loss: 0.2936 (0.036 sec)
# Epoch: 5 Iteration: 50 : Loss: 0.2959 (0.036 sec)
# Epoch: 5 Iteration: 53 : Loss: 0.3075 (0.040 sec)
# Epoch: 5 Iteration: 56 : Loss: 0.3038 (0.036 sec)
# Epoch: 5 Iteration: 59 : Loss: 0.2997 (0.036 sec)
# Epoch: 6 Iteration: 3 : Loss: 0.2969 (0.036 sec)
# Epoch: 6 Iteration: 6 : Loss: 0.2983 (0.036 sec)
# Epoch: 6 Iteration: 9 : Loss: 0.2896 (0.036 sec)
# Epoch: 6 Iteration: 12 : Loss: 0.2929 (0.037 sec)
# Epoch: 6 Iteration: 15 : Loss: 0.2982 (0.037 sec)
# Epoch: 6 Iteration: 18 : Loss: 0.3041 (0.036 sec)
# Epoch: 6 Iteration: 21 : Loss: 0.2922 (0.037 sec)
# Epoch: 6 Iteration: 24 : Loss: 0.3049 (0.037 sec)
# Epoch: 6 Iteration: 27 : Loss: 0.3094 (0.036 sec)
# Epoch: 6 Iteration: 30 : Loss: 0.3223 (0.036 sec)
# Epoch: 6 Iteration: 33 : Loss: 0.3009 (0.036 sec)
# Epoch: 6 Iteration: 36 : Loss: 0.2894 (0.037 sec)
# Epoch: 6 Iteration: 39 : Loss: 0.3023 (0.035 sec)
# Epoch: 6 Iteration: 42 : Loss: 0.2889 (0.036 sec)
# Epoch: 6 Iteration: 45 : Loss: 0.3046 (0.036 sec)
# Epoch: 6 Iteration: 48 : Loss: 0.3004 (0.036 sec)
# Epoch: 6 Iteration: 51 : Loss: 0.3068 (0.036 sec)
# Epoch: 6 Iteration: 54 : Loss: 0.3208 (0.036 sec)
# Epoch: 6 Iteration: 57 : Loss: 0.2897 (0.036 sec)
# Epoch: 7 Iteration: 1 : Loss: 0.3023 (0.036 sec)
# Epoch: 7 Iteration: 4 : Loss: 0.2791 (0.036 sec)
# Epoch: 7 Iteration: 7 : Loss: 0.2974 (0.036 sec)
# Epoch: 7 Iteration: 10 : Loss: 0.3063 (0.036 sec)
# Epoch: 7 Iteration: 13 : Loss: 0.2818 (0.036 sec)
# Epoch: 7 Iteration: 16 : Loss: 0.3129 (0.036 sec)
# Epoch: 7 Iteration: 19 : Loss: 0.3074 (0.037 sec)
# Epoch: 7 Iteration: 22 : Loss: 0.2994 (0.036 sec)
# Epoch: 7 Iteration: 25 : Loss: 0.2855 (0.042 sec)
# Epoch: 7 Iteration: 28 : Loss: 0.3117 (0.036 sec)
# Epoch: 7 Iteration: 31 : Loss: 0.2954 (0.036 sec)
# Epoch: 7 Iteration: 34 : Loss: 0.3056 (0.036 sec)
# Epoch: 7 Iteration: 37 : Loss: 0.3083 (0.036 sec)
# Epoch: 7 Iteration: 40 : Loss: 0.2971 (0.036 sec)
# Epoch: 7 Iteration: 43 : Loss: 0.2975 (0.036 sec)
# Epoch: 7 Iteration: 46 : Loss: 0.3116 (0.036 sec)
# Epoch: 7 Iteration: 49 : Loss: 0.3082 (0.036 sec)
# Epoch: 7 Iteration: 52 : Loss: 0.2939 (0.036 sec)
# Epoch: 7 Iteration: 55 : Loss: 0.3106 (0.035 sec)
# Epoch: 7 Iteration: 58 : Loss: 0.3166 (0.036 sec)
# Epoch: 8 Iteration: 2 : Loss: 0.2993 (0.037 sec)
# Epoch: 8 Iteration: 5 : Loss: 0.2964 (0.036 sec)
# Epoch: 8 Iteration: 8 : Loss: 0.2810 (0.036 sec)
# Epoch: 8 Iteration: 11 : Loss: 0.3075 (0.035 sec)
# Epoch: 8 Iteration: 14 : Loss: 0.2815 (0.036 sec)
# Epoch: 8 Iteration: 17 : Loss: 0.2990 (0.036 sec)
# Epoch: 8 Iteration: 20 : Loss: 0.2951 (0.037 sec)
# Epoch: 8 Iteration: 23 : Loss: 0.2877 (0.036 sec)
# Epoch: 8 Iteration: 26 : Loss: 0.2977 (0.036 sec)
# Saving at epoch 8 step: 28
# Epoch: 8 Iteration: 29 : Loss: 0.2931 (0.035 sec)
# Epoch: 8 Iteration: 32 : Loss: 0.3067 (0.040 sec)
# Epoch: 8 Iteration: 35 : Loss: 0.3011 (0.035 sec)
# Epoch: 8 Iteration: 38 : Loss: 0.2889 (0.036 sec)
# Epoch: 8 Iteration: 41 : Loss: 0.3007 (0.036 sec)
# Epoch: 8 Iteration: 44 : Loss: 0.3044 (0.036 sec)
# Epoch: 8 Iteration: 47 : Loss: 0.2934 (0.036 sec)
# Epoch: 8 Iteration: 50 : Loss: 0.3053 (0.036 sec)
# Epoch: 8 Iteration: 53 : Loss: 0.2936 (0.036 sec)
# Epoch: 8 Iteration: 56 : Loss: 0.3016 (0.036 sec)
# Epoch: 8 Iteration: 59 : Loss: 0.3028 (0.036 sec)
# Epoch: 9 Iteration: 3 : Loss: 0.2861 (0.036 sec)
# Epoch: 9 Iteration: 6 : Loss: 0.2801 (0.036 sec)
# Epoch: 9 Iteration: 9 : Loss: 0.2927 (0.037 sec)
# Epoch: 9 Iteration: 12 : Loss: 0.3202 (0.036 sec)
# Epoch: 9 Iteration: 15 : Loss: 0.2858 (0.036 sec)
# Epoch: 9 Iteration: 18 : Loss: 0.2953 (0.036 sec)
# Epoch: 9 Iteration: 21 : Loss: 0.2826 (0.036 sec)
# Epoch: 9 Iteration: 24 : Loss: 0.3074 (0.036 sec)
# Epoch: 9 Iteration: 27 : Loss: 0.2924 (0.036 sec)
# Epoch: 9 Iteration: 30 : Loss: 0.3064 (0.036 sec)
# Epoch: 9 Iteration: 33 : Loss: 0.3107 (0.036 sec)
# Epoch: 9 Iteration: 36 : Loss: 0.2928 (0.036 sec)
# Epoch: 9 Iteration: 39 : Loss: 0.2973 (0.037 sec)
# Epoch: 9 Iteration: 42 : Loss: 0.3226 (0.036 sec)
# Epoch: 9 Iteration: 45 : Loss: 0.3094 (0.035 sec)
# Epoch: 9 Iteration: 48 : Loss: 0.2853 (0.037 sec)
# Epoch: 9 Iteration: 51 : Loss: 0.3064 (0.037 sec)
# Epoch: 9 Iteration: 54 : Loss: 0.3145 (0.036 sec)
# Epoch: 9 Iteration: 57 : Loss: 0.3102 (0.036 sec)
# Epoch: 10 Iteration: 1 : Loss: 0.2957 (0.036 sec)
# Epoch: 10 Iteration: 4 : Loss: 0.2870 (0.035 sec)
# Epoch: 10 Iteration: 7 : Loss: 0.2991 (0.035 sec)
# Epoch: 10 Iteration: 10 : Loss: 0.3023 (0.036 sec)
# Epoch: 10 Iteration: 13 : Loss: 0.2935 (0.036 sec)
# Epoch: 10 Iteration: 16 : Loss: 0.2838 (0.035 sec)
# Epoch: 10 Iteration: 19 : Loss: 0.2917 (0.036 sec)
# Epoch: 10 Iteration: 22 : Loss: 0.2916 (0.035 sec)
# Epoch: 10 Iteration: 25 : Loss: 0.3100 (0.043 sec)
# Epoch: 10 Iteration: 28 : Loss: 0.2936 (0.036 sec)
# Epoch: 10 Iteration: 31 : Loss: 0.3051 (0.036 sec)
# Epoch: 10 Iteration: 34 : Loss: 0.3080 (0.035 sec)
# Epoch: 10 Iteration: 37 : Loss: 0.2957 (0.036 sec)
# Epoch: 10 Iteration: 40 : Loss: 0.3101 (0.035 sec)
# Epoch: 10 Iteration: 43 : Loss: 0.3018 (0.035 sec)
# Epoch: 10 Iteration: 46 : Loss: 0.2867 (0.035 sec)
# Epoch: 10 Iteration: 49 : Loss: 0.2880 (0.036 sec)
# Epoch: 10 Iteration: 52 : Loss: 0.2998 (0.035 sec)
# Epoch: 10 Iteration: 55 : Loss: 0.3017 (0.035 sec)
# Epoch: 10 Iteration: 58 : Loss: 0.3026 (0.036 sec)
# Epoch: 11 Iteration: 2 : Loss: 0.2823 (0.036 sec)
# Epoch: 11 Iteration: 5 : Loss: 0.3166 (0.036 sec)
# Epoch: 11 Iteration: 8 : Loss: 0.2816 (0.037 sec)
# Epoch: 11 Iteration: 11 : Loss: 0.3034 (0.036 sec)
# Epoch: 11 Iteration: 14 : Loss: 0.2782 (0.035 sec)
# Epoch: 11 Iteration: 17 : Loss: 0.3179 (0.037 sec)
# Epoch: 11 Iteration: 20 : Loss: 0.3053 (0.037 sec)
# Epoch: 11 Iteration: 23 : Loss: 0.2979 (0.036 sec)
# Epoch: 11 Iteration: 26 : Loss: 0.3064 (0.036 sec)
# Epoch: 11 Iteration: 29 : Loss: 0.2866 (0.036 sec)
# Epoch: 11 Iteration: 32 : Loss: 0.2947 (0.036 sec)
# Epoch: 11 Iteration: 35 : Loss: 0.3044 (0.036 sec)
# Epoch: 11 Iteration: 38 : Loss: 0.2970 (0.045 sec)
# Epoch: 11 Iteration: 41 : Loss: 0.2967 (0.036 sec)
# Epoch: 11 Iteration: 44 : Loss: 0.3068 (0.036 sec)
# Epoch: 11 Iteration: 47 : Loss: 0.3187 (0.037 sec)
# Epoch: 11 Iteration: 50 : Loss: 0.2927 (0.036 sec)
# Epoch: 11 Iteration: 53 : Loss: 0.2947 (0.036 sec)
# Epoch: 11 Iteration: 56 : Loss: 0.2941 (0.037 sec)
# Epoch: 11 Iteration: 59 : Loss: 0.2958 (0.037 sec)
# Epoch: 12 Iteration: 3 : Loss: 0.2838 (0.036 sec)
# Epoch: 12 Iteration: 6 : Loss: 0.2801 (0.036 sec)
# Epoch: 12 Iteration: 9 : Loss: 0.3011 (0.036 sec)
# Epoch: 12 Iteration: 12 : Loss: 0.3055 (0.036 sec)
# Epoch: 12 Iteration: 15 : Loss: 0.2964 (0.036 sec)
# Epoch: 12 Iteration: 18 : Loss: 0.2868 (0.036 sec)
# Epoch: 12 Iteration: 21 : Loss: 0.2845 (0.036 sec)
# Epoch: 12 Iteration: 24 : Loss: 0.2979 (0.045 sec)
# Epoch: 12 Iteration: 27 : Loss: 0.2979 (0.036 sec)
# Epoch: 12 Iteration: 30 : Loss: 0.2866 (0.037 sec)
# Epoch: 12 Iteration: 33 : Loss: 0.3048 (0.036 sec)
# Epoch: 12 Iteration: 36 : Loss: 0.2872 (0.036 sec)
# Epoch: 12 Iteration: 39 : Loss: 0.3049 (0.036 sec)
# Epoch: 12 Iteration: 42 : Loss: 0.2920 (0.037 sec)
# Saving at epoch 12 step: 42
# Epoch: 12 Iteration: 45 : Loss: 0.2837 (0.035 sec)
# Epoch: 12 Iteration: 48 : Loss: 0.2942 (0.036 sec)
# Epoch: 12 Iteration: 51 : Loss: 0.3060 (0.036 sec)
# Epoch: 12 Iteration: 54 : Loss: 0.2925 (0.037 sec)
# Epoch: 12 Iteration: 57 : Loss: 0.2857 (0.036 sec)
# Epoch: 13 Iteration: 1 : Loss: 0.2881 (0.035 sec)
# Epoch: 13 Iteration: 4 : Loss: 0.2893 (0.035 sec)
# Epoch: 13 Iteration: 7 : Loss: 0.2933 (0.036 sec)
# Epoch: 13 Iteration: 10 : Loss: 0.2928 (0.036 sec)
# Epoch: 13 Iteration: 13 : Loss: 0.3039 (0.035 sec)
# Epoch: 13 Iteration: 16 : Loss: 0.2795 (0.036 sec)
# Epoch: 13 Iteration: 19 : Loss: 0.2974 (0.036 sec)
# Epoch: 13 Iteration: 22 : Loss: 0.2923 (0.035 sec)
# Epoch: 13 Iteration: 25 : Loss: 0.2841 (0.036 sec)
# Epoch: 13 Iteration: 28 : Loss: 0.2784 (0.036 sec)
# Epoch: 13 Iteration: 31 : Loss: 0.2973 (0.035 sec)
# Epoch: 13 Iteration: 34 : Loss: 0.2805 (0.035 sec)
# Epoch: 13 Iteration: 37 : Loss: 0.2947 (0.037 sec)
# Epoch: 13 Iteration: 40 : Loss: 0.2901 (0.036 sec)
# Epoch: 13 Iteration: 43 : Loss: 0.2901 (0.036 sec)
# Epoch: 13 Iteration: 46 : Loss: 0.2855 (0.036 sec)
# Epoch: 13 Iteration: 49 : Loss: 0.2920 (0.036 sec)
# Epoch: 13 Iteration: 52 : Loss: 0.2762 (0.036 sec)
# Epoch: 13 Iteration: 55 : Loss: 0.2940 (0.035 sec)
# Epoch: 13 Iteration: 58 : Loss: 0.2853 (0.035 sec)
# Epoch: 14 Iteration: 2 : Loss: 0.2899 (0.036 sec)
# Epoch: 14 Iteration: 5 : Loss: 0.2984 (0.036 sec)
# Epoch: 14 Iteration: 8 : Loss: 0.2862 (0.037 sec)
# Epoch: 14 Iteration: 11 : Loss: 0.2893 (0.037 sec)
# Epoch: 14 Iteration: 14 : Loss: 0.2925 (0.036 sec)
# Epoch: 14 Iteration: 17 : Loss: 0.2846 (0.036 sec)
# Epoch: 14 Iteration: 20 : Loss: 0.2831 (0.036 sec)
# Epoch: 14 Iteration: 23 : Loss: 0.3137 (0.037 sec)
# Epoch: 14 Iteration: 26 : Loss: 0.2928 (0.036 sec)
# Epoch: 14 Iteration: 29 : Loss: 0.2960 (0.044 sec)
# Epoch: 14 Iteration: 32 : Loss: 0.2995 (0.037 sec)
# Epoch: 14 Iteration: 35 : Loss: 0.2958 (0.038 sec)
# Epoch: 14 Iteration: 38 : Loss: 0.3006 (0.037 sec)
# Epoch: 14 Iteration: 41 : Loss: 0.2924 (0.036 sec)
# Epoch: 14 Iteration: 44 : Loss: 0.3010 (0.038 sec)
# Epoch: 14 Iteration: 47 : Loss: 0.2913 (0.036 sec)
# Epoch: 14 Iteration: 50 : Loss: 0.2932 (0.036 sec)
# Epoch: 14 Iteration: 53 : Loss: 0.2988 (0.036 sec)
# Epoch: 14 Iteration: 56 : Loss: 0.2898 (0.043 sec)
# Epoch: 14 Iteration: 59 : Loss: 0.3078 (0.036 sec)
# Epoch: 15 Iteration: 3 : Loss: 0.3032 (0.036 sec)
# Epoch: 15 Iteration: 6 : Loss: 0.3035 (0.036 sec)
# Epoch: 15 Iteration: 9 : Loss: 0.3126 (0.037 sec)
# Epoch: 15 Iteration: 12 : Loss: 0.2959 (0.036 sec)
# Epoch: 15 Iteration: 15 : Loss: 0.2776 (0.037 sec)
# Epoch: 15 Iteration: 18 : Loss: 0.2930 (0.036 sec)
# Epoch: 15 Iteration: 21 : Loss: 0.2997 (0.036 sec)
# Epoch: 15 Iteration: 24 : Loss: 0.2884 (0.036 sec)
# Epoch: 15 Iteration: 27 : Loss: 0.2846 (0.036 sec)
# Epoch: 15 Iteration: 30 : Loss: 0.2872 (0.036 sec)
# Epoch: 15 Iteration: 33 : Loss: 0.2792 (0.043 sec)
# Epoch: 15 Iteration: 36 : Loss: 0.2832 (0.036 sec)
# Epoch: 15 Iteration: 39 : Loss: 0.3259 (0.036 sec)
# Epoch: 15 Iteration: 42 : Loss: 0.2777 (0.037 sec)
# Epoch: 15 Iteration: 45 : Loss: 0.2903 (0.040 sec)
# Epoch: 15 Iteration: 48 : Loss: 0.3013 (0.036 sec)
# Epoch: 15 Iteration: 51 : Loss: 0.2815 (0.035 sec)
# Epoch: 15 Iteration: 54 : Loss: 0.2991 (0.036 sec)
# Epoch: 15 Iteration: 57 : Loss: 0.2862 (0.036 sec)
# Epoch: 16 Iteration: 1 : Loss: 0.2959 (0.038 sec)
# Epoch: 16 Iteration: 4 : Loss: 0.2885 (0.036 sec)
# Epoch: 16 Iteration: 7 : Loss: 0.2914 (0.036 sec)
# Epoch: 16 Iteration: 10 : Loss: 0.2923 (0.036 sec)
# Epoch: 16 Iteration: 13 : Loss: 0.2944 (0.036 sec)
# Epoch: 16 Iteration: 16 : Loss: 0.2942 (0.035 sec)
# Epoch: 16 Iteration: 19 : Loss: 0.2760 (0.036 sec)
# Epoch: 16 Iteration: 22 : Loss: 0.2994 (0.035 sec)
# Epoch: 16 Iteration: 25 : Loss: 0.3083 (0.036 sec)
# Epoch: 16 Iteration: 28 : Loss: 0.2863 (0.036 sec)
# Epoch: 16 Iteration: 31 : Loss: 0.2957 (0.036 sec)
# Epoch: 16 Iteration: 34 : Loss: 0.3008 (0.035 sec)
# Epoch: 16 Iteration: 37 : Loss: 0.2997 (0.035 sec)
# Epoch: 16 Iteration: 40 : Loss: 0.3000 (0.036 sec)
# Epoch: 16 Iteration: 43 : Loss: 0.2927 (0.036 sec)
# Epoch: 16 Iteration: 46 : Loss: 0.2849 (0.035 sec)
# Epoch: 16 Iteration: 49 : Loss: 0.2912 (0.035 sec)
# Epoch: 16 Iteration: 52 : Loss: 0.2901 (0.036 sec)
# Epoch: 16 Iteration: 55 : Loss: 0.2881 (0.036 sec)
# Saving at epoch 16 step: 56
# Epoch: 16 Iteration: 58 : Loss: 0.2687 (0.036 sec)
# Epoch: 17 Iteration: 2 : Loss: 0.2951 (0.036 sec)
# Epoch: 17 Iteration: 5 : Loss: 0.2995 (0.035 sec)
# Epoch: 17 Iteration: 8 : Loss: 0.2824 (0.036 sec)
# Epoch: 17 Iteration: 11 : Loss: 0.2968 (0.036 sec)
# Epoch: 17 Iteration: 14 : Loss: 0.2866 (0.036 sec)
# Epoch: 17 Iteration: 17 : Loss: 0.2894 (0.036 sec)
# Epoch: 17 Iteration: 20 : Loss: 0.2826 (0.037 sec)
# Epoch: 17 Iteration: 23 : Loss: 0.2917 (0.036 sec)
# Epoch: 17 Iteration: 26 : Loss: 0.2847 (0.037 sec)
# Epoch: 17 Iteration: 29 : Loss: 0.2969 (0.036 sec)
# Epoch: 17 Iteration: 32 : Loss: 0.2931 (0.036 sec)
# Epoch: 17 Iteration: 35 : Loss: 0.2945 (0.036 sec)
# Epoch: 17 Iteration: 38 : Loss: 0.2915 (0.037 sec)
# Epoch: 17 Iteration: 41 : Loss: 0.3006 (0.036 sec)
# Epoch: 17 Iteration: 44 : Loss: 0.2952 (0.036 sec)
# Epoch: 17 Iteration: 47 : Loss: 0.2772 (0.036 sec)
# Epoch: 17 Iteration: 50 : Loss: 0.2936 (0.036 sec)
# Epoch: 17 Iteration: 53 : Loss: 0.3006 (0.037 sec)
# Epoch: 17 Iteration: 56 : Loss: 0.2932 (0.036 sec)
# Epoch: 17 Iteration: 59 : Loss: 0.2942 (0.036 sec)
# Epoch: 18 Iteration: 3 : Loss: 0.2900 (0.036 sec)
# Epoch: 18 Iteration: 6 : Loss: 0.3139 (0.036 sec)
# Epoch: 18 Iteration: 9 : Loss: 0.3005 (0.036 sec)
# Epoch: 18 Iteration: 12 : Loss: 0.2931 (0.043 sec)
# Epoch: 18 Iteration: 15 : Loss: 0.2881 (0.037 sec)
# Epoch: 18 Iteration: 18 : Loss: 0.2898 (0.037 sec)
# Epoch: 18 Iteration: 21 : Loss: 0.2910 (0.036 sec)
# Epoch: 18 Iteration: 24 : Loss: 0.2759 (0.037 sec)
# Epoch: 18 Iteration: 27 : Loss: 0.3144 (0.036 sec)
# Epoch: 18 Iteration: 30 : Loss: 0.2823 (0.037 sec)
# Epoch: 18 Iteration: 33 : Loss: 0.2862 (0.036 sec)
# Epoch: 18 Iteration: 36 : Loss: 0.2924 (0.037 sec)
# Epoch: 18 Iteration: 39 : Loss: 0.2955 (0.040 sec)
# Epoch: 18 Iteration: 42 : Loss: 0.2936 (0.036 sec)
# Epoch: 18 Iteration: 45 : Loss: 0.3013 (0.036 sec)
# Epoch: 18 Iteration: 48 : Loss: 0.2934 (0.036 sec)
# Epoch: 18 Iteration: 51 : Loss: 0.2834 (0.036 sec)
# Epoch: 18 Iteration: 54 : Loss: 0.2925 (0.036 sec)
# Epoch: 18 Iteration: 57 : Loss: 0.3044 (0.036 sec)
# Epoch: 19 Iteration: 1 : Loss: 0.2853 (0.036 sec)
# Epoch: 19 Iteration: 4 : Loss: 0.2883 (0.035 sec)
# Epoch: 19 Iteration: 7 : Loss: 0.2723 (0.036 sec)
# Epoch: 19 Iteration: 10 : Loss: 0.2897 (0.036 sec)
# Epoch: 19 Iteration: 13 : Loss: 0.2950 (0.037 sec)
# Epoch: 19 Iteration: 16 : Loss: 0.2922 (0.036 sec)
# Epoch: 19 Iteration: 19 : Loss: 0.2883 (0.036 sec)
# Epoch: 19 Iteration: 22 : Loss: 0.2901 (0.035 sec)
# Epoch: 19 Iteration: 25 : Loss: 0.2956 (0.037 sec)
# Epoch: 19 Iteration: 28 : Loss: 0.2943 (0.035 sec)
# Epoch: 19 Iteration: 31 : Loss: 0.2716 (0.036 sec)
# Epoch: 19 Iteration: 34 : Loss: 0.2773 (0.036 sec)
# Epoch: 19 Iteration: 37 : Loss: 0.2863 (0.036 sec)
# Epoch: 19 Iteration: 40 : Loss: 0.2906 (0.035 sec)
# Epoch: 19 Iteration: 43 : Loss: 0.2974 (0.035 sec)
# Epoch: 19 Iteration: 46 : Loss: 0.2983 (0.036 sec)
# Epoch: 19 Iteration: 49 : Loss: 0.2881 (0.036 sec)
# Epoch: 19 Iteration: 52 : Loss: 0.2706 (0.035 sec)
# Epoch: 19 Iteration: 55 : Loss: 0.2809 (0.036 sec)
# Epoch: 19 Iteration: 58 : Loss: 0.2776 (0.035 sec)
# Epoch: 20 Iteration: 2 : Loss: 0.2913 (0.036 sec)
# Epoch: 20 Iteration: 5 : Loss: 0.2764 (0.036 sec)
# Epoch: 20 Iteration: 8 : Loss: 0.2872 (0.037 sec)
# Epoch: 20 Iteration: 11 : Loss: 0.2857 (0.036 sec)
# Epoch: 20 Iteration: 14 : Loss: 0.3015 (0.036 sec)
# Epoch: 20 Iteration: 17 : Loss: 0.2866 (0.037 sec)
# Epoch: 20 Iteration: 20 : Loss: 0.2831 (0.036 sec)
# Epoch: 20 Iteration: 23 : Loss: 0.2968 (0.035 sec)
# Epoch: 20 Iteration: 26 : Loss: 0.2868 (0.036 sec)
# Epoch: 20 Iteration: 29 : Loss: 0.2763 (0.036 sec)
# Epoch: 20 Iteration: 32 : Loss: 0.2940 (0.036 sec)
# Epoch: 20 Iteration: 35 : Loss: 0.2754 (0.036 sec)
# Epoch: 20 Iteration: 38 : Loss: 0.2874 (0.036 sec)
# Epoch: 20 Iteration: 41 : Loss: 0.2901 (0.037 sec)
# Epoch: 20 Iteration: 44 : Loss: 0.3042 (0.036 sec)
# Epoch: 20 Iteration: 47 : Loss: 0.3002 (0.036 sec)
# Epoch: 20 Iteration: 50 : Loss: 0.2871 (0.035 sec)
# Epoch: 20 Iteration: 53 : Loss: 0.2805 (0.036 sec)
# Epoch: 20 Iteration: 56 : Loss: 0.2929 (0.037 sec)
# Epoch: 20 Iteration: 59 : Loss: 0.2832 (0.036 sec)
# Epoch: 21 Iteration: 3 : Loss: 0.2862 (0.036 sec)
# Epoch: 21 Iteration: 6 : Loss: 0.2933 (0.036 sec)
# Epoch: 21 Iteration: 9 : Loss: 0.2878 (0.036 sec)
# Saving at epoch 21 step: 11
# Epoch: 21 Iteration: 12 : Loss: 0.2979 (0.039 sec)
# Epoch: 21 Iteration: 15 : Loss: 0.2790 (0.036 sec)
# Epoch: 21 Iteration: 18 : Loss: 0.2932 (0.036 sec)
# Epoch: 21 Iteration: 21 : Loss: 0.2890 (0.036 sec)
# Epoch: 21 Iteration: 24 : Loss: 0.2742 (0.036 sec)
# Epoch: 21 Iteration: 27 : Loss: 0.2913 (0.036 sec)
# Epoch: 21 Iteration: 30 : Loss: 0.2948 (0.036 sec)
# Epoch: 21 Iteration: 33 : Loss: 0.2856 (0.036 sec)
# Epoch: 21 Iteration: 36 : Loss: 0.2746 (0.036 sec)
# Epoch: 21 Iteration: 39 : Loss: 0.2853 (0.037 sec)
# Epoch: 21 Iteration: 42 : Loss: 0.2864 (0.036 sec)
# Epoch: 21 Iteration: 45 : Loss: 0.2946 (0.035 sec)
# Epoch: 21 Iteration: 48 : Loss: 0.2972 (0.036 sec)
# Epoch: 21 Iteration: 51 : Loss: 0.2697 (0.036 sec)
# Epoch: 21 Iteration: 54 : Loss: 0.2818 (0.035 sec)
# Epoch: 21 Iteration: 57 : Loss: 0.3031 (0.037 sec)
# Epoch: 22 Iteration: 1 : Loss: 0.2805 (0.036 sec)
# Epoch: 22 Iteration: 4 : Loss: 0.2816 (0.036 sec)
# Epoch: 22 Iteration: 7 : Loss: 0.2718 (0.036 sec)
# Epoch: 22 Iteration: 10 : Loss: 0.2859 (0.036 sec)
# Epoch: 22 Iteration: 13 : Loss: 0.2780 (0.036 sec)
# Epoch: 22 Iteration: 16 : Loss: 0.2852 (0.036 sec)
# Epoch: 22 Iteration: 19 : Loss: 0.2750 (0.038 sec)
# Epoch: 22 Iteration: 22 : Loss: 0.2872 (0.036 sec)
# Epoch: 22 Iteration: 25 : Loss: 0.2825 (0.036 sec)
# Epoch: 22 Iteration: 28 : Loss: 0.3069 (0.036 sec)
# Epoch: 22 Iteration: 31 : Loss: 0.2863 (0.036 sec)
# Epoch: 22 Iteration: 34 : Loss: 0.2951 (0.036 sec)
# Epoch: 22 Iteration: 37 : Loss: 0.2726 (0.036 sec)
# Epoch: 22 Iteration: 40 : Loss: 0.2983 (0.036 sec)
# Epoch: 22 Iteration: 43 : Loss: 0.2871 (0.036 sec)
# Epoch: 22 Iteration: 46 : Loss: 0.2747 (0.036 sec)
# Epoch: 22 Iteration: 49 : Loss: 0.2919 (0.035 sec)
# Epoch: 22 Iteration: 52 : Loss: 0.2969 (0.037 sec)
# Epoch: 22 Iteration: 55 : Loss: 0.3172 (0.036 sec)
# Epoch: 22 Iteration: 58 : Loss: 0.2982 (0.040 sec)
# Epoch: 23 Iteration: 2 : Loss: 0.2900 (0.036 sec)
# Epoch: 23 Iteration: 5 : Loss: 0.2810 (0.036 sec)
# Epoch: 23 Iteration: 8 : Loss: 0.2947 (0.037 sec)
# Epoch: 23 Iteration: 11 : Loss: 0.2867 (0.037 sec)
# Epoch: 23 Iteration: 14 : Loss: 0.2864 (0.035 sec)
# Epoch: 23 Iteration: 17 : Loss: 0.2792 (0.036 sec)
# Epoch: 23 Iteration: 20 : Loss: 0.2803 (0.036 sec)
# Epoch: 23 Iteration: 23 : Loss: 0.2778 (0.036 sec)
# Epoch: 23 Iteration: 26 : Loss: 0.2813 (0.036 sec)
# Epoch: 23 Iteration: 29 : Loss: 0.2932 (0.036 sec)
# Epoch: 23 Iteration: 32 : Loss: 0.2851 (0.035 sec)
# Epoch: 23 Iteration: 35 : Loss: 0.2986 (0.037 sec)
# Epoch: 23 Iteration: 38 : Loss: 0.2896 (0.035 sec)
# Epoch: 23 Iteration: 41 : Loss: 0.3013 (0.036 sec)
# Epoch: 23 Iteration: 44 : Loss: 0.2862 (0.035 sec)
# Epoch: 23 Iteration: 47 : Loss: 0.2950 (0.036 sec)
# Epoch: 23 Iteration: 50 : Loss: 0.3012 (0.036 sec)
# Epoch: 23 Iteration: 53 : Loss: 0.2998 (0.035 sec)
# Epoch: 23 Iteration: 56 : Loss: 0.2828 (0.035 sec)
# Epoch: 23 Iteration: 59 : Loss: 0.3049 (0.037 sec)
# Epoch: 24 Iteration: 3 : Loss: 0.3040 (0.036 sec)
# Epoch: 24 Iteration: 6 : Loss: 0.3047 (0.036 sec)
# Epoch: 24 Iteration: 9 : Loss: 0.2810 (0.036 sec)
# Epoch: 24 Iteration: 12 : Loss: 0.2925 (0.036 sec)
# Epoch: 24 Iteration: 15 : Loss: 0.2873 (0.036 sec)
# Epoch: 24 Iteration: 18 : Loss: 0.2958 (0.036 sec)
# Epoch: 24 Iteration: 21 : Loss: 0.2958 (0.036 sec)
# Epoch: 24 Iteration: 24 : Loss: 0.2909 (0.035 sec)
# Epoch: 24 Iteration: 27 : Loss: 0.3010 (0.036 sec)
# Epoch: 24 Iteration: 30 : Loss: 0.2997 (0.036 sec)
# Epoch: 24 Iteration: 33 : Loss: 0.2686 (0.036 sec)
# Epoch: 24 Iteration: 36 : Loss: 0.2814 (0.036 sec)
# Epoch: 24 Iteration: 39 : Loss: 0.2721 (0.036 sec)
# Epoch: 24 Iteration: 42 : Loss: 0.2903 (0.035 sec)
# Epoch: 24 Iteration: 45 : Loss: 0.2810 (0.036 sec)
# Epoch: 24 Iteration: 48 : Loss: 0.2988 (0.036 sec)
# Epoch: 24 Iteration: 51 : Loss: 0.2671 (0.035 sec)
# Epoch: 24 Iteration: 54 : Loss: 0.3022 (0.036 sec)
# Epoch: 24 Iteration: 57 : Loss: 0.2922 (0.036 sec)
# Epoch: 25 Iteration: 1 : Loss: 0.3025 (0.036 sec)
# Epoch: 25 Iteration: 4 : Loss: 0.2750 (0.036 sec)
# Epoch: 25 Iteration: 7 : Loss: 0.2735 (0.036 sec)
# Epoch: 25 Iteration: 10 : Loss: 0.2689 (0.037 sec)
# Epoch: 25 Iteration: 13 : Loss: 0.2845 (0.036 sec)
# Epoch: 25 Iteration: 16 : Loss: 0.2976 (0.036 sec)
# Epoch: 25 Iteration: 19 : Loss: 0.2841 (0.036 sec)
# Epoch: 25 Iteration: 22 : Loss: 0.2791 (0.036 sec)
# Epoch: 25 Iteration: 25 : Loss: 0.2786 (0.051 sec)
# Saving at epoch 25 step: 25
# Epoch: 25 Iteration: 28 : Loss: 0.2895 (0.036 sec)
# Epoch: 25 Iteration: 31 : Loss: 0.2940 (0.039 sec)
# Epoch: 25 Iteration: 34 : Loss: 0.2870 (0.036 sec)
# Epoch: 25 Iteration: 37 : Loss: 0.2858 (0.035 sec)
# Epoch: 25 Iteration: 40 : Loss: 0.2850 (0.036 sec)
# Epoch: 25 Iteration: 43 : Loss: 0.2874 (0.036 sec)
# Epoch: 25 Iteration: 46 : Loss: 0.2998 (0.036 sec)
# Epoch: 25 Iteration: 49 : Loss: 0.3027 (0.036 sec)
# Epoch: 25 Iteration: 52 : Loss: 0.2903 (0.036 sec)
# Epoch: 25 Iteration: 55 : Loss: 0.2871 (0.036 sec)
# Epoch: 25 Iteration: 58 : Loss: 0.2997 (0.036 sec)
# Epoch: 26 Iteration: 2 : Loss: 0.2866 (0.036 sec)
# Epoch: 26 Iteration: 5 : Loss: 0.2866 (0.036 sec)
# Epoch: 26 Iteration: 8 : Loss: 0.2618 (0.036 sec)
# Epoch: 26 Iteration: 11 : Loss: 0.3052 (0.036 sec)
# Epoch: 26 Iteration: 14 : Loss: 0.2798 (0.036 sec)
# Epoch: 26 Iteration: 17 : Loss: 0.2761 (0.035 sec)
# Epoch: 26 Iteration: 20 : Loss: 0.2962 (0.036 sec)
# Epoch: 26 Iteration: 23 : Loss: 0.2729 (0.036 sec)
# Epoch: 26 Iteration: 26 : Loss: 0.2784 (0.036 sec)
# Epoch: 26 Iteration: 29 : Loss: 0.2773 (0.035 sec)
# Epoch: 26 Iteration: 32 : Loss: 0.2739 (0.038 sec)
# Epoch: 26 Iteration: 35 : Loss: 0.2833 (0.036 sec)
# Epoch: 26 Iteration: 38 : Loss: 0.2788 (0.036 sec)
# Epoch: 26 Iteration: 41 : Loss: 0.2852 (0.036 sec)
# Epoch: 26 Iteration: 44 : Loss: 0.2931 (0.036 sec)
# Epoch: 26 Iteration: 47 : Loss: 0.2873 (0.037 sec)
# Epoch: 26 Iteration: 50 : Loss: 0.2873 (0.036 sec)
# Epoch: 26 Iteration: 53 : Loss: 0.2929 (0.036 sec)
# Epoch: 26 Iteration: 56 : Loss: 0.3065 (0.037 sec)
# Epoch: 26 Iteration: 59 : Loss: 0.2981 (0.036 sec)
# Epoch: 27 Iteration: 3 : Loss: 0.2904 (0.036 sec)
# Epoch: 27 Iteration: 6 : Loss: 0.2699 (0.036 sec)
# Epoch: 27 Iteration: 9 : Loss: 0.2719 (0.035 sec)
# Epoch: 27 Iteration: 12 : Loss: 0.2882 (0.036 sec)
# Epoch: 27 Iteration: 15 : Loss: 0.2797 (0.035 sec)
# Epoch: 27 Iteration: 18 : Loss: 0.2956 (0.036 sec)
# Epoch: 27 Iteration: 21 : Loss: 0.2814 (0.036 sec)
# Epoch: 27 Iteration: 24 : Loss: 0.2767 (0.036 sec)
# Epoch: 27 Iteration: 27 : Loss: 0.2846 (0.035 sec)
# Epoch: 27 Iteration: 30 : Loss: 0.2926 (0.036 sec)
# Epoch: 27 Iteration: 33 : Loss: 0.2811 (0.036 sec)
# Epoch: 27 Iteration: 36 : Loss: 0.2904 (0.036 sec)
# Epoch: 27 Iteration: 39 : Loss: 0.2953 (0.035 sec)
# Epoch: 27 Iteration: 42 : Loss: 0.2849 (0.036 sec)
# Epoch: 27 Iteration: 45 : Loss: 0.2841 (0.036 sec)
# Epoch: 27 Iteration: 48 : Loss: 0.2852 (0.036 sec)
# Epoch: 27 Iteration: 51 : Loss: 0.2852 (0.035 sec)
# Epoch: 27 Iteration: 54 : Loss: 0.2856 (0.036 sec)
# Epoch: 27 Iteration: 57 : Loss: 0.2957 (0.036 sec)
# Epoch: 28 Iteration: 1 : Loss: 0.2969 (0.036 sec)
# Epoch: 28 Iteration: 4 : Loss: 0.2833 (0.036 sec)
# Epoch: 28 Iteration: 7 : Loss: 0.2901 (0.036 sec)
# Epoch: 28 Iteration: 10 : Loss: 0.2817 (0.036 sec)
# Epoch: 28 Iteration: 13 : Loss: 0.2853 (0.036 sec)
# Epoch: 28 Iteration: 16 : Loss: 0.3009 (0.036 sec)
# Epoch: 28 Iteration: 19 : Loss: 0.2913 (0.045 sec)
# Epoch: 28 Iteration: 22 : Loss: 0.2838 (0.035 sec)
# Epoch: 28 Iteration: 25 : Loss: 0.2787 (0.036 sec)
# Epoch: 28 Iteration: 28 : Loss: 0.2995 (0.036 sec)
# Epoch: 28 Iteration: 31 : Loss: 0.2940 (0.037 sec)
# Epoch: 28 Iteration: 34 : Loss: 0.2751 (0.036 sec)
# Epoch: 28 Iteration: 37 : Loss: 0.2880 (0.035 sec)
# Epoch: 28 Iteration: 40 : Loss: 0.2738 (0.036 sec)
# Epoch: 28 Iteration: 43 : Loss: 0.2825 (0.036 sec)
# Epoch: 28 Iteration: 46 : Loss: 0.2817 (0.037 sec)
# Epoch: 28 Iteration: 49 : Loss: 0.2935 (0.036 sec)
# Epoch: 28 Iteration: 52 : Loss: 0.2726 (0.037 sec)
# Epoch: 28 Iteration: 55 : Loss: 0.2724 (0.036 sec)
# Epoch: 28 Iteration: 58 : Loss: 0.2710 (0.037 sec)
# Epoch: 29 Iteration: 2 : Loss: 0.2819 (0.036 sec)
# Epoch: 29 Iteration: 5 : Loss: 0.2713 (0.036 sec)
# Epoch: 29 Iteration: 8 : Loss: 0.2776 (0.036 sec)
# Epoch: 29 Iteration: 11 : Loss: 0.2878 (0.044 sec)
# Epoch: 29 Iteration: 14 : Loss: 0.2701 (0.036 sec)
# Epoch: 29 Iteration: 17 : Loss: 0.2755 (0.036 sec)
# Epoch: 29 Iteration: 20 : Loss: 0.2845 (0.036 sec)
# Epoch: 29 Iteration: 23 : Loss: 0.2697 (0.035 sec)
# Epoch: 29 Iteration: 26 : Loss: 0.2860 (0.036 sec)
# Epoch: 29 Iteration: 29 : Loss: 0.2859 (0.036 sec)
# Epoch: 29 Iteration: 32 : Loss: 0.3080 (0.035 sec)
# Epoch: 29 Iteration: 35 : Loss: 0.2756 (0.036 sec)
# Epoch: 29 Iteration: 38 : Loss: 0.2757 (0.038 sec)
# Saving at epoch 29 step: 39
# Epoch: 29 Iteration: 41 : Loss: 0.3064 (0.036 sec)
# Epoch: 29 Iteration: 44 : Loss: 0.2798 (0.037 sec)
# Epoch: 29 Iteration: 47 : Loss: 0.2867 (0.036 sec)
# Epoch: 29 Iteration: 50 : Loss: 0.2864 (0.036 sec)
# Epoch: 29 Iteration: 53 : Loss: 0.2709 (0.036 sec)
# Epoch: 29 Iteration: 56 : Loss: 0.2812 (0.036 sec)
# Epoch: 29 Iteration: 59 : Loss: 0.2831 (0.036 sec)
# Epoch: 30 Iteration: 3 : Loss: 0.2721 (0.036 sec)
# Epoch: 30 Iteration: 6 : Loss: 0.2846 (0.036 sec)
# Epoch: 30 Iteration: 9 : Loss: 0.2751 (0.036 sec)
# Epoch: 30 Iteration: 12 : Loss: 0.2826 (0.036 sec)
# Epoch: 30 Iteration: 15 : Loss: 0.2869 (0.037 sec)
# Epoch: 30 Iteration: 18 : Loss: 0.2888 (0.036 sec)
# Epoch: 30 Iteration: 21 : Loss: 0.2779 (0.037 sec)
# Epoch: 30 Iteration: 24 : Loss: 0.2762 (0.036 sec)
# Epoch: 30 Iteration: 27 : Loss: 0.2822 (0.037 sec)
# Epoch: 30 Iteration: 30 : Loss: 0.2852 (0.036 sec)
# Epoch: 30 Iteration: 33 : Loss: 0.2855 (0.036 sec)
# Epoch: 30 Iteration: 36 : Loss: 0.2792 (0.036 sec)
# Epoch: 30 Iteration: 39 : Loss: 0.2985 (0.036 sec)
# Epoch: 30 Iteration: 42 : Loss: 0.2720 (0.036 sec)
# Epoch: 30 Iteration: 45 : Loss: 0.2746 (0.036 sec)
# Epoch: 30 Iteration: 48 : Loss: 0.2887 (0.036 sec)
# Epoch: 30 Iteration: 51 : Loss: 0.2852 (0.037 sec)
# Epoch: 30 Iteration: 54 : Loss: 0.2917 (0.036 sec)
# Epoch: 30 Iteration: 57 : Loss: 0.2804 (0.035 sec)
# Epoch: 31 Iteration: 1 : Loss: 0.2721 (0.036 sec)
# Epoch: 31 Iteration: 4 : Loss: 0.2717 (0.035 sec)
# Epoch: 31 Iteration: 7 : Loss: 0.2908 (0.036 sec)
# Epoch: 31 Iteration: 10 : Loss: 0.2983 (0.044 sec)
# Epoch: 31 Iteration: 13 : Loss: 0.2743 (0.036 sec)
# Epoch: 31 Iteration: 16 : Loss: 0.2832 (0.036 sec)
# Epoch: 31 Iteration: 19 : Loss: 0.2669 (0.036 sec)
# Epoch: 31 Iteration: 22 : Loss: 0.2673 (0.036 sec)
# Epoch: 31 Iteration: 25 : Loss: 0.2870 (0.036 sec)
# Epoch: 31 Iteration: 28 : Loss: 0.2820 (0.036 sec)
# Epoch: 31 Iteration: 31 : Loss: 0.2700 (0.036 sec)
# Epoch: 31 Iteration: 34 : Loss: 0.2797 (0.036 sec)
# Epoch: 31 Iteration: 37 : Loss: 0.2737 (0.036 sec)
# Epoch: 31 Iteration: 40 : Loss: 0.3037 (0.035 sec)
# Epoch: 31 Iteration: 43 : Loss: 0.2742 (0.036 sec)
# Epoch: 31 Iteration: 46 : Loss: 0.2839 (0.036 sec)
# Epoch: 31 Iteration: 49 : Loss: 0.2672 (0.036 sec)
# Epoch: 31 Iteration: 52 : Loss: 0.2922 (0.036 sec)
# Epoch: 31 Iteration: 55 : Loss: 0.2813 (0.036 sec)
# Epoch: 31 Iteration: 58 : Loss: 0.2825 (0.037 sec)
# Epoch: 32 Iteration: 2 : Loss: 0.2926 (0.036 sec)
# Epoch: 32 Iteration: 5 : Loss: 0.2687 (0.036 sec)
# Epoch: 32 Iteration: 8 : Loss: 0.2836 (0.036 sec)
# Epoch: 32 Iteration: 11 : Loss: 0.2784 (0.036 sec)
# Epoch: 32 Iteration: 14 : Loss: 0.2818 (0.036 sec)
# Epoch: 32 Iteration: 17 : Loss: 0.2710 (0.038 sec)
# Epoch: 32 Iteration: 20 : Loss: 0.2705 (0.036 sec)
# Epoch: 32 Iteration: 23 : Loss: 0.2866 (0.036 sec)
# Epoch: 32 Iteration: 26 : Loss: 0.2837 (0.036 sec)
# Epoch: 32 Iteration: 29 : Loss: 0.2816 (0.036 sec)
# Epoch: 32 Iteration: 32 : Loss: 0.2789 (0.035 sec)
# Epoch: 32 Iteration: 35 : Loss: 0.2748 (0.036 sec)
# Epoch: 32 Iteration: 38 : Loss: 0.2843 (0.035 sec)
# Epoch: 32 Iteration: 41 : Loss: 0.2794 (0.035 sec)
# Epoch: 32 Iteration: 44 : Loss: 0.3004 (0.037 sec)
# Epoch: 32 Iteration: 47 : Loss: 0.2690 (0.036 sec)
# Epoch: 32 Iteration: 50 : Loss: 0.2996 (0.036 sec)
# Epoch: 32 Iteration: 53 : Loss: 0.2852 (0.035 sec)
# Epoch: 32 Iteration: 56 : Loss: 0.2764 (0.036 sec)
# Epoch: 32 Iteration: 59 : Loss: 0.2728 (0.038 sec)
# Epoch: 33 Iteration: 3 : Loss: 0.2697 (0.036 sec)
# Epoch: 33 Iteration: 6 : Loss: 0.2684 (0.036 sec)
# Epoch: 33 Iteration: 9 : Loss: 0.2733 (0.039 sec)
# Epoch: 33 Iteration: 12 : Loss: 0.2778 (0.036 sec)
# Epoch: 33 Iteration: 15 : Loss: 0.2889 (0.036 sec)
# Epoch: 33 Iteration: 18 : Loss: 0.2909 (0.037 sec)
# Epoch: 33 Iteration: 21 : Loss: 0.2744 (0.037 sec)
# Epoch: 33 Iteration: 24 : Loss: 0.2810 (0.036 sec)
# Epoch: 33 Iteration: 27 : Loss: 0.2979 (0.036 sec)
# Epoch: 33 Iteration: 30 : Loss: 0.2787 (0.037 sec)
# Epoch: 33 Iteration: 33 : Loss: 0.2768 (0.035 sec)
# Epoch: 33 Iteration: 36 : Loss: 0.2850 (0.036 sec)
# Epoch: 33 Iteration: 39 : Loss: 0.2735 (0.036 sec)
# Epoch: 33 Iteration: 42 : Loss: 0.2764 (0.035 sec)
# Epoch: 33 Iteration: 45 : Loss: 0.2782 (0.036 sec)
# Epoch: 33 Iteration: 48 : Loss: 0.2775 (0.036 sec)
# Epoch: 33 Iteration: 51 : Loss: 0.2734 (0.036 sec)
# Saving at epoch 33 step: 53
# Epoch: 33 Iteration: 54 : Loss: 0.2692 (0.036 sec)
# Epoch: 33 Iteration: 57 : Loss: 0.2824 (0.036 sec)
# Epoch: 34 Iteration: 1 : Loss: 0.2798 (0.036 sec)
# Epoch: 34 Iteration: 4 : Loss: 0.2965 (0.036 sec)
# Epoch: 34 Iteration: 7 : Loss: 0.2812 (0.037 sec)
# Epoch: 34 Iteration: 10 : Loss: 0.2674 (0.036 sec)
# Epoch: 34 Iteration: 13 : Loss: 0.2584 (0.035 sec)
# Epoch: 34 Iteration: 16 : Loss: 0.2737 (0.036 sec)
# Epoch: 34 Iteration: 19 : Loss: 0.2776 (0.037 sec)
# Epoch: 34 Iteration: 22 : Loss: 0.2637 (0.035 sec)
# Epoch: 34 Iteration: 25 : Loss: 0.2892 (0.036 sec)
# Epoch: 34 Iteration: 28 : Loss: 0.2679 (0.035 sec)
# Epoch: 34 Iteration: 31 : Loss: 0.2721 (0.035 sec)
# Epoch: 34 Iteration: 34 : Loss: 0.2703 (0.036 sec)
# Epoch: 34 Iteration: 37 : Loss: 0.2890 (0.036 sec)
# Epoch: 34 Iteration: 40 : Loss: 0.2789 (0.036 sec)
# Epoch: 34 Iteration: 43 : Loss: 0.2807 (0.039 sec)
# Epoch: 34 Iteration: 46 : Loss: 0.2781 (0.036 sec)
# Epoch: 34 Iteration: 49 : Loss: 0.2926 (0.036 sec)
# Epoch: 34 Iteration: 52 : Loss: 0.2762 (0.036 sec)
# Epoch: 34 Iteration: 55 : Loss: 0.2805 (0.036 sec)
# Epoch: 34 Iteration: 58 : Loss: 0.2640 (0.036 sec)
# Epoch: 35 Iteration: 2 : Loss: 0.2659 (0.036 sec)
# Epoch: 35 Iteration: 5 : Loss: 0.2914 (0.035 sec)
# Epoch: 35 Iteration: 8 : Loss: 0.2781 (0.036 sec)
# Epoch: 35 Iteration: 11 : Loss: 0.2603 (0.036 sec)
# Epoch: 35 Iteration: 14 : Loss: 0.2675 (0.037 sec)
# Epoch: 35 Iteration: 17 : Loss: 0.2833 (0.036 sec)
# Epoch: 35 Iteration: 20 : Loss: 0.2845 (0.035 sec)
# Epoch: 35 Iteration: 23 : Loss: 0.2742 (0.037 sec)
# Epoch: 35 Iteration: 26 : Loss: 0.2721 (0.037 sec)
# Epoch: 35 Iteration: 29 : Loss: 0.2804 (0.036 sec)
# Epoch: 35 Iteration: 32 : Loss: 0.2772 (0.036 sec)
# Epoch: 35 Iteration: 35 : Loss: 0.2804 (0.036 sec)
# Epoch: 35 Iteration: 38 : Loss: 0.2815 (0.035 sec)
# Epoch: 35 Iteration: 41 : Loss: 0.2813 (0.035 sec)
# Epoch: 35 Iteration: 44 : Loss: 0.2773 (0.036 sec)
# Epoch: 35 Iteration: 47 : Loss: 0.2960 (0.036 sec)
# Epoch: 35 Iteration: 50 : Loss: 0.2778 (0.035 sec)
# Epoch: 35 Iteration: 53 : Loss: 0.2781 (0.036 sec)
# Epoch: 35 Iteration: 56 : Loss: 0.2901 (0.036 sec)
# Epoch: 35 Iteration: 59 : Loss: 0.2673 (0.035 sec)
# Epoch: 36 Iteration: 3 : Loss: 0.2805 (0.036 sec)
# Epoch: 36 Iteration: 6 : Loss: 0.2814 (0.035 sec)
# Epoch: 36 Iteration: 9 : Loss: 0.2812 (0.036 sec)
# Epoch: 36 Iteration: 12 : Loss: 0.2701 (0.036 sec)
# Epoch: 36 Iteration: 15 : Loss: 0.2644 (0.038 sec)
# Epoch: 36 Iteration: 18 : Loss: 0.2679 (0.035 sec)
# Epoch: 36 Iteration: 21 : Loss: 0.2833 (0.037 sec)
# Epoch: 36 Iteration: 24 : Loss: 0.2782 (0.036 sec)
# Epoch: 36 Iteration: 27 : Loss: 0.2770 (0.035 sec)
# Epoch: 36 Iteration: 30 : Loss: 0.2685 (0.036 sec)
# Epoch: 36 Iteration: 33 : Loss: 0.2748 (0.035 sec)
# Epoch: 36 Iteration: 36 : Loss: 0.2705 (0.036 sec)
# Epoch: 36 Iteration: 39 : Loss: 0.2690 (0.036 sec)
# Epoch: 36 Iteration: 42 : Loss: 0.2817 (0.036 sec)
# Epoch: 36 Iteration: 45 : Loss: 0.2662 (0.036 sec)
# Epoch: 36 Iteration: 48 : Loss: 0.2764 (0.037 sec)
# Epoch: 36 Iteration: 51 : Loss: 0.2788 (0.036 sec)
# Epoch: 36 Iteration: 54 : Loss: 0.2890 (0.036 sec)
# Epoch: 36 Iteration: 57 : Loss: 0.2849 (0.035 sec)
# Epoch: 37 Iteration: 1 : Loss: 0.2515 (0.036 sec)
# Epoch: 37 Iteration: 4 : Loss: 0.2674 (0.036 sec)
# Epoch: 37 Iteration: 7 : Loss: 0.2804 (0.037 sec)
# Epoch: 37 Iteration: 10 : Loss: 0.2685 (0.035 sec)
# Epoch: 37 Iteration: 13 : Loss: 0.2729 (0.035 sec)
# Epoch: 37 Iteration: 16 : Loss: 0.2688 (0.040 sec)
# Epoch: 37 Iteration: 19 : Loss: 0.2890 (0.036 sec)
# Epoch: 37 Iteration: 22 : Loss: 0.2682 (0.036 sec)
# Epoch: 37 Iteration: 25 : Loss: 0.2848 (0.035 sec)
# Epoch: 37 Iteration: 28 : Loss: 0.2795 (0.035 sec)
# Epoch: 37 Iteration: 31 : Loss: 0.2756 (0.036 sec)
# Epoch: 37 Iteration: 34 : Loss: 0.2770 (0.036 sec)
# Epoch: 37 Iteration: 37 : Loss: 0.2879 (0.035 sec)
# Epoch: 37 Iteration: 40 : Loss: 0.2847 (0.036 sec)
# Epoch: 37 Iteration: 43 : Loss: 0.2925 (0.036 sec)
# Epoch: 37 Iteration: 46 : Loss: 0.2642 (0.036 sec)
# Epoch: 37 Iteration: 49 : Loss: 0.2756 (0.036 sec)
# Epoch: 37 Iteration: 52 : Loss: 0.2725 (0.042 sec)
# Epoch: 37 Iteration: 55 : Loss: 0.2672 (0.036 sec)
# Epoch: 37 Iteration: 58 : Loss: 0.2730 (0.036 sec)
# Epoch: 38 Iteration: 2 : Loss: 0.2771 (0.036 sec)
# Epoch: 38 Iteration: 5 : Loss: 0.2695 (0.035 sec)
# Epoch: 38 Iteration: 8 : Loss: 0.2869 (0.036 sec)
# Saving at epoch 38 step: 8
# Epoch: 38 Iteration: 11 : Loss: 0.2743 (0.036 sec)
# Epoch: 38 Iteration: 14 : Loss: 0.2869 (0.036 sec)
# Epoch: 38 Iteration: 17 : Loss: 0.2945 (0.037 sec)
# Epoch: 38 Iteration: 20 : Loss: 0.2780 (0.037 sec)
# Epoch: 38 Iteration: 23 : Loss: 0.2962 (0.037 sec)
# Epoch: 38 Iteration: 26 : Loss: 0.2701 (0.043 sec)
# Epoch: 38 Iteration: 29 : Loss: 0.2633 (0.036 sec)
# Epoch: 38 Iteration: 32 : Loss: 0.2988 (0.036 sec)
# Epoch: 38 Iteration: 35 : Loss: 0.2770 (0.036 sec)
# Epoch: 38 Iteration: 38 : Loss: 0.2875 (0.036 sec)
# Epoch: 38 Iteration: 41 : Loss: 0.2778 (0.035 sec)
# Epoch: 38 Iteration: 44 : Loss: 0.2777 (0.036 sec)
# Epoch: 38 Iteration: 47 : Loss: 0.2848 (0.038 sec)
# Epoch: 38 Iteration: 50 : Loss: 0.2786 (0.036 sec)
# Epoch: 38 Iteration: 53 : Loss: 0.2772 (0.036 sec)
# Epoch: 38 Iteration: 56 : Loss: 0.2796 (0.036 sec)
# Epoch: 38 Iteration: 59 : Loss: 0.2828 (0.036 sec)
# Epoch: 39 Iteration: 3 : Loss: 0.2746 (0.036 sec)
# Epoch: 39 Iteration: 6 : Loss: 0.2766 (0.036 sec)
# Epoch: 39 Iteration: 9 : Loss: 0.2697 (0.035 sec)
# Epoch: 39 Iteration: 12 : Loss: 0.2528 (0.036 sec)
# Epoch: 39 Iteration: 15 : Loss: 0.2750 (0.036 sec)
# Epoch: 39 Iteration: 18 : Loss: 0.2906 (0.036 sec)
# Epoch: 39 Iteration: 21 : Loss: 0.2758 (0.036 sec)
# Epoch: 39 Iteration: 24 : Loss: 0.2836 (0.036 sec)
# Epoch: 39 Iteration: 27 : Loss: 0.2757 (0.036 sec)
# Epoch: 39 Iteration: 30 : Loss: 0.2915 (0.036 sec)
# Epoch: 39 Iteration: 33 : Loss: 0.2575 (0.036 sec)
# Epoch: 39 Iteration: 36 : Loss: 0.2764 (0.036 sec)
# Epoch: 39 Iteration: 39 : Loss: 0.2650 (0.036 sec)
# Epoch: 39 Iteration: 42 : Loss: 0.2765 (0.036 sec)
# Epoch: 39 Iteration: 45 : Loss: 0.2804 (0.035 sec)
# Epoch: 39 Iteration: 48 : Loss: 0.2629 (0.036 sec)
# Epoch: 39 Iteration: 51 : Loss: 0.2877 (0.035 sec)
# Epoch: 39 Iteration: 54 : Loss: 0.2888 (0.040 sec)
# Epoch: 39 Iteration: 57 : Loss: 0.2828 (0.036 sec)
# Epoch: 40 Iteration: 1 : Loss: 0.2805 (0.036 sec)
# Epoch: 40 Iteration: 4 : Loss: 0.2818 (0.035 sec)
# Epoch: 40 Iteration: 7 : Loss: 0.2977 (0.036 sec)
# Epoch: 40 Iteration: 10 : Loss: 0.2768 (0.036 sec)
# Epoch: 40 Iteration: 13 : Loss: 0.2796 (0.044 sec)
# Epoch: 40 Iteration: 16 : Loss: 0.2802 (0.036 sec)
# Epoch: 40 Iteration: 19 : Loss: 0.2886 (0.036 sec)
# Epoch: 40 Iteration: 22 : Loss: 0.2740 (0.036 sec)
# Epoch: 40 Iteration: 25 : Loss: 0.2827 (0.036 sec)
# Epoch: 40 Iteration: 28 : Loss: 0.2654 (0.037 sec)
# Epoch: 40 Iteration: 31 : Loss: 0.2766 (0.035 sec)
# Epoch: 40 Iteration: 34 : Loss: 0.2929 (0.036 sec)
# Epoch: 40 Iteration: 37 : Loss: 0.2808 (0.036 sec)
# Epoch: 40 Iteration: 40 : Loss: 0.2819 (0.036 sec)
# Epoch: 40 Iteration: 43 : Loss: 0.2711 (0.036 sec)
# Epoch: 40 Iteration: 46 : Loss: 0.2875 (0.036 sec)
# Epoch: 40 Iteration: 49 : Loss: 0.2992 (0.036 sec)
# Epoch: 40 Iteration: 52 : Loss: 0.2809 (0.036 sec)
# Epoch: 40 Iteration: 55 : Loss: 0.2851 (0.035 sec)
# Epoch: 40 Iteration: 58 : Loss: 0.2915 (0.036 sec)
# Epoch: 41 Iteration: 2 : Loss: 0.2738 (0.036 sec)
# Epoch: 41 Iteration: 5 : Loss: 0.2597 (0.037 sec)
# Epoch: 41 Iteration: 8 : Loss: 0.2774 (0.035 sec)
# Epoch: 41 Iteration: 11 : Loss: 0.2781 (0.036 sec)
# Epoch: 41 Iteration: 14 : Loss: 0.2903 (0.036 sec)
# Epoch: 41 Iteration: 17 : Loss: 0.2788 (0.036 sec)
# Epoch: 41 Iteration: 20 : Loss: 0.2764 (0.044 sec)
# Epoch: 41 Iteration: 23 : Loss: 0.2817 (0.036 sec)
# Epoch: 41 Iteration: 26 : Loss: 0.2836 (0.036 sec)
# Epoch: 41 Iteration: 29 : Loss: 0.2986 (0.036 sec)
# Epoch: 41 Iteration: 32 : Loss: 0.2771 (0.036 sec)
# Epoch: 41 Iteration: 35 : Loss: 0.2720 (0.037 sec)
# Epoch: 41 Iteration: 38 : Loss: 0.2732 (0.036 sec)
# Epoch: 41 Iteration: 41 : Loss: 0.2754 (0.035 sec)
# Epoch: 41 Iteration: 44 : Loss: 0.2887 (0.036 sec)
# Epoch: 41 Iteration: 47 : Loss: 0.2748 (0.036 sec)
# Epoch: 41 Iteration: 50 : Loss: 0.2774 (0.036 sec)
# Epoch: 41 Iteration: 53 : Loss: 0.2862 (0.036 sec)
# Epoch: 41 Iteration: 56 : Loss: 0.2754 (0.036 sec)
# Epoch: 41 Iteration: 59 : Loss: 0.2654 (0.036 sec)
# Epoch: 42 Iteration: 3 : Loss: 0.2846 (0.036 sec)
# Epoch: 42 Iteration: 6 : Loss: 0.2853 (0.036 sec)
# Epoch: 42 Iteration: 9 : Loss: 0.2847 (0.035 sec)
# Epoch: 42 Iteration: 12 : Loss: 0.2865 (0.036 sec)
# Epoch: 42 Iteration: 15 : Loss: 0.2838 (0.036 sec)
# Epoch: 42 Iteration: 18 : Loss: 0.2689 (0.036 sec)
# Epoch: 42 Iteration: 21 : Loss: 0.2770 (0.036 sec)
# Saving at epoch 42 step: 22
# Epoch: 42 Iteration: 24 : Loss: 0.2662 (0.036 sec)
# Epoch: 42 Iteration: 27 : Loss: 0.2878 (0.035 sec)
# Epoch: 42 Iteration: 30 : Loss: 0.2892 (0.036 sec)
# Epoch: 42 Iteration: 33 : Loss: 0.2719 (0.036 sec)
# Epoch: 42 Iteration: 36 : Loss: 0.2624 (0.036 sec)
# Epoch: 42 Iteration: 39 : Loss: 0.2620 (0.036 sec)
# Epoch: 42 Iteration: 42 : Loss: 0.2775 (0.036 sec)
# Epoch: 42 Iteration: 45 : Loss: 0.2662 (0.036 sec)
# Epoch: 42 Iteration: 48 : Loss: 0.2790 (0.036 sec)
# Epoch: 42 Iteration: 51 : Loss: 0.2743 (0.036 sec)
# Epoch: 42 Iteration: 54 : Loss: 0.2822 (0.036 sec)
# Epoch: 42 Iteration: 57 : Loss: 0.2676 (0.036 sec)
# Epoch: 43 Iteration: 1 : Loss: 0.2768 (0.036 sec)
# Epoch: 43 Iteration: 4 : Loss: 0.2784 (0.036 sec)
# Epoch: 43 Iteration: 7 : Loss: 0.2905 (0.036 sec)
# Epoch: 43 Iteration: 10 : Loss: 0.2672 (0.036 sec)
# Epoch: 43 Iteration: 13 : Loss: 0.2634 (0.036 sec)
# Epoch: 43 Iteration: 16 : Loss: 0.2632 (0.035 sec)
# Epoch: 43 Iteration: 19 : Loss: 0.2726 (0.044 sec)
# Epoch: 43 Iteration: 22 : Loss: 0.2585 (0.036 sec)
# Epoch: 43 Iteration: 25 : Loss: 0.2861 (0.036 sec)
# Epoch: 43 Iteration: 28 : Loss: 0.2671 (0.036 sec)
# Epoch: 43 Iteration: 31 : Loss: 0.2683 (0.036 sec)
# Epoch: 43 Iteration: 34 : Loss: 0.2854 (0.036 sec)
# Epoch: 43 Iteration: 37 : Loss: 0.2860 (0.036 sec)
# Epoch: 43 Iteration: 40 : Loss: 0.2716 (0.036 sec)
# Epoch: 43 Iteration: 43 : Loss: 0.2760 (0.037 sec)
# Epoch: 43 Iteration: 46 : Loss: 0.2745 (0.036 sec)
# Epoch: 43 Iteration: 49 : Loss: 0.2783 (0.036 sec)
# Epoch: 43 Iteration: 52 : Loss: 0.2794 (0.046 sec)
# Epoch: 43 Iteration: 55 : Loss: 0.2823 (0.035 sec)
# Epoch: 43 Iteration: 58 : Loss: 0.2724 (0.038 sec)
# Epoch: 44 Iteration: 2 : Loss: 0.2740 (0.036 sec)
# Epoch: 44 Iteration: 5 : Loss: 0.2811 (0.036 sec)
# Epoch: 44 Iteration: 8 : Loss: 0.2790 (0.036 sec)
# Epoch: 44 Iteration: 11 : Loss: 0.2849 (0.036 sec)
# Epoch: 44 Iteration: 14 : Loss: 0.2735 (0.036 sec)
# Epoch: 44 Iteration: 17 : Loss: 0.2736 (0.035 sec)
# Epoch: 44 Iteration: 20 : Loss: 0.2703 (0.037 sec)
# Epoch: 44 Iteration: 23 : Loss: 0.2895 (0.036 sec)
# Epoch: 44 Iteration: 26 : Loss: 0.2835 (0.040 sec)
# Epoch: 44 Iteration: 29 : Loss: 0.2662 (0.038 sec)
# Epoch: 44 Iteration: 32 : Loss: 0.2837 (0.037 sec)
# Epoch: 44 Iteration: 35 : Loss: 0.2739 (0.036 sec)
# Epoch: 44 Iteration: 38 : Loss: 0.2657 (0.036 sec)
# Epoch: 44 Iteration: 41 : Loss: 0.2799 (0.036 sec)
# Epoch: 44 Iteration: 44 : Loss: 0.2795 (0.036 sec)
# Epoch: 44 Iteration: 47 : Loss: 0.2807 (0.036 sec)
# Epoch: 44 Iteration: 50 : Loss: 0.2843 (0.036 sec)
# Epoch: 44 Iteration: 53 : Loss: 0.2699 (0.041 sec)
# Epoch: 44 Iteration: 56 : Loss: 0.2842 (0.036 sec)
# Epoch: 44 Iteration: 59 : Loss: 0.2790 (0.036 sec)
# Epoch: 45 Iteration: 3 : Loss: 0.2676 (0.036 sec)
# Epoch: 45 Iteration: 6 : Loss: 0.2674 (0.035 sec)
# Epoch: 45 Iteration: 9 : Loss: 0.2825 (0.036 sec)
# Epoch: 45 Iteration: 12 : Loss: 0.2783 (0.039 sec)
# Epoch: 45 Iteration: 15 : Loss: 0.2531 (0.037 sec)
# Epoch: 45 Iteration: 18 : Loss: 0.2704 (0.036 sec)
# Epoch: 45 Iteration: 21 : Loss: 0.2750 (0.035 sec)
# Epoch: 45 Iteration: 24 : Loss: 0.2778 (0.035 sec)
# Epoch: 45 Iteration: 27 : Loss: 0.2777 (0.035 sec)
# Epoch: 45 Iteration: 30 : Loss: 0.2709 (0.036 sec)
# Epoch: 45 Iteration: 33 : Loss: 0.2717 (0.036 sec)
# Epoch: 45 Iteration: 36 : Loss: 0.2722 (0.036 sec)
# Epoch: 45 Iteration: 39 : Loss: 0.2818 (0.036 sec)
# Epoch: 45 Iteration: 42 : Loss: 0.2786 (0.035 sec)
# Epoch: 45 Iteration: 45 : Loss: 0.2743 (0.036 sec)
# Epoch: 45 Iteration: 48 : Loss: 0.2676 (0.037 sec)
# Epoch: 45 Iteration: 51 : Loss: 0.2870 (0.036 sec)
# Epoch: 45 Iteration: 54 : Loss: 0.2874 (0.036 sec)
# Epoch: 45 Iteration: 57 : Loss: 0.2675 (0.035 sec)
# Epoch: 46 Iteration: 1 : Loss: 0.2727 (0.035 sec)
# Epoch: 46 Iteration: 4 : Loss: 0.2571 (0.036 sec)
# Epoch: 46 Iteration: 7 : Loss: 0.2823 (0.035 sec)
# Epoch: 46 Iteration: 10 : Loss: 0.2638 (0.036 sec)
# Epoch: 46 Iteration: 13 : Loss: 0.2690 (0.036 sec)
# Epoch: 46 Iteration: 16 : Loss: 0.2715 (0.036 sec)
# Epoch: 46 Iteration: 19 : Loss: 0.2665 (0.036 sec)
# Epoch: 46 Iteration: 22 : Loss: 0.2632 (0.036 sec)
# Epoch: 46 Iteration: 25 : Loss: 0.2793 (0.035 sec)
# Epoch: 46 Iteration: 28 : Loss: 0.2702 (0.036 sec)
# Epoch: 46 Iteration: 31 : Loss: 0.2754 (0.036 sec)
# Epoch: 46 Iteration: 34 : Loss: 0.2821 (0.036 sec)
# Saving at epoch 46 step: 36
# Epoch: 46 Iteration: 37 : Loss: 0.2690 (0.036 sec)
# Epoch: 46 Iteration: 40 : Loss: 0.2755 (0.036 sec)
# Epoch: 46 Iteration: 43 : Loss: 0.2754 (0.036 sec)
# Epoch: 46 Iteration: 46 : Loss: 0.2781 (0.035 sec)
# Epoch: 46 Iteration: 49 : Loss: 0.2822 (0.036 sec)
# Epoch: 46 Iteration: 52 : Loss: 0.2694 (0.036 sec)
# Epoch: 46 Iteration: 55 : Loss: 0.2679 (0.036 sec)
# Epoch: 46 Iteration: 58 : Loss: 0.2758 (0.036 sec)
# Epoch: 47 Iteration: 2 : Loss: 0.2643 (0.037 sec)
# Epoch: 47 Iteration: 5 : Loss: 0.2715 (0.036 sec)
# Epoch: 47 Iteration: 8 : Loss: 0.2619 (0.036 sec)
# Epoch: 47 Iteration: 11 : Loss: 0.2695 (0.036 sec)
# Epoch: 47 Iteration: 14 : Loss: 0.2726 (0.036 sec)
# Epoch: 47 Iteration: 17 : Loss: 0.2640 (0.036 sec)
# Epoch: 47 Iteration: 20 : Loss: 0.2728 (0.037 sec)
# Epoch: 47 Iteration: 23 : Loss: 0.2659 (0.036 sec)
# Epoch: 47 Iteration: 26 : Loss: 0.2916 (0.036 sec)
# Epoch: 47 Iteration: 29 : Loss: 0.2757 (0.036 sec)
# Epoch: 47 Iteration: 32 : Loss: 0.2804 (0.036 sec)
# Epoch: 47 Iteration: 35 : Loss: 0.2798 (0.038 sec)
# Epoch: 47 Iteration: 38 : Loss: 0.2739 (0.036 sec)
# Epoch: 47 Iteration: 41 : Loss: 0.2677 (0.036 sec)
# Epoch: 47 Iteration: 44 : Loss: 0.2681 (0.036 sec)
# ...
# Epoch: 1645 Iteration: 55 : Loss: 0.1985 (0.036 sec)
# Epoch: 1645 Iteration: 58 : Loss: 0.2094 (0.036 sec)
# Epoch: 1646 Iteration: 2 : Loss: 0.1993 (0.038 sec)
# Epoch: 1646 Iteration: 5 : Loss: 0.2139 (0.035 sec)
# Epoch: 1646 Iteration: 8 : Loss: 0.2064 (0.036 sec)
# Epoch: 1646 Iteration: 11 : Loss: 0.2254 (0.036 sec)
# Epoch: 1646 Iteration: 14 : Loss: 0.2214 (0.035 sec)
# Epoch: 1646 Iteration: 17 : Loss: 0.2033 (0.036 sec)
# Epoch: 1646 Iteration: 20 : Loss: 0.2225 (0.041 sec)
# Epoch: 1646 Iteration: 23 : Loss: 0.2325 (0.036 sec)
# Epoch: 1646 Iteration: 26 : Loss: 0.2029 (0.039 sec)
# Epoch: 1646 Iteration: 29 : Loss: 0.2060 (0.036 sec)
# Epoch: 1646 Iteration: 32 : Loss: 0.2008 (0.036 sec)
# Epoch: 1646 Iteration: 35 : Loss: 0.2153 (0.036 sec)
# Epoch: 1646 Iteration: 38 : Loss: 0.2256 (0.044 sec)
# Epoch: 1646 Iteration: 41 : Loss: 0.2117 (0.035 sec)
# Epoch: 1646 Iteration: 44 : Loss: 0.2045 (0.036 sec)
# Epoch: 1646 Iteration: 47 : Loss: 0.2189 (0.036 sec)
# Epoch: 1646 Iteration: 50 : Loss: 0.2142 (0.036 sec)
# Epoch: 1646 Iteration: 53 : Loss: 0.2232 (0.035 sec)
# Epoch: 1646 Iteration: 56 : Loss: 0.2202 (0.044 sec)
# Epoch: 1646 Iteration: 59 : Loss: 0.2080 (0.036 sec)
# Epoch: 1647 Iteration: 3 : Loss: 0.2150 (0.036 sec)
# Epoch: 1647 Iteration: 6 : Loss: 0.2104 (0.043 sec)
# Epoch: 1647 Iteration: 9 : Loss: 0.2181 (0.036 sec)
# Epoch: 1647 Iteration: 12 : Loss: 0.2153 (0.036 sec)
# Epoch: 1647 Iteration: 15 : Loss: 0.1897 (0.037 sec)
# Epoch: 1647 Iteration: 18 : Loss: 0.2063 (0.036 sec)
# Epoch: 1647 Iteration: 21 : Loss: 0.2030 (0.036 sec)
# Epoch: 1647 Iteration: 24 : Loss: 0.2085 (0.036 sec)
# Epoch: 1647 Iteration: 27 : Loss: 0.2173 (0.036 sec)
# Epoch: 1647 Iteration: 30 : Loss: 0.2157 (0.036 sec)
# Epoch: 1647 Iteration: 33 : Loss: 0.2205 (0.036 sec)
# Epoch: 1647 Iteration: 36 : Loss: 0.2170 (0.036 sec)
# Epoch: 1647 Iteration: 39 : Loss: 0.2072 (0.036 sec)
# Epoch: 1647 Iteration: 42 : Loss: 0.2132 (0.036 sec)
# Epoch: 1647 Iteration: 45 : Loss: 0.2119 (0.036 sec)
# Epoch: 1647 Iteration: 48 : Loss: 0.2036 (0.036 sec)
# Epoch: 1647 Iteration: 51 : Loss: 0.2154 (0.036 sec)
# Epoch: 1647 Iteration: 54 : Loss: 0.2269 (0.036 sec)
# Epoch: 1647 Iteration: 57 : Loss: 0.2058 (0.037 sec)
# Epoch: 1648 Iteration: 1 : Loss: 0.2157 (0.036 sec)
# Epoch: 1648 Iteration: 4 : Loss: 0.2041 (0.043 sec)
# Epoch: 1648 Iteration: 7 : Loss: 0.2109 (0.036 sec)
# Epoch: 1648 Iteration: 10 : Loss: 0.2181 (0.035 sec)
# Epoch: 1648 Iteration: 13 : Loss: 0.2340 (0.037 sec)
# Epoch: 1648 Iteration: 16 : Loss: 0.1998 (0.035 sec)
# Saving at epoch 1648 step: 18
# Epoch: 1648 Iteration: 19 : Loss: 0.2257 (0.036 sec)
# Epoch: 1648 Iteration: 22 : Loss: 0.2184 (0.037 sec)
# Epoch: 1648 Iteration: 25 : Loss: 0.2233 (0.036 sec)
# Epoch: 1648 Iteration: 28 : Loss: 0.2075 (0.036 sec)
# Epoch: 1648 Iteration: 31 : Loss: 0.1910 (0.036 sec)
# Epoch: 1648 Iteration: 34 : Loss: 0.2246 (0.036 sec)
# Epoch: 1648 Iteration: 37 : Loss: 0.2159 (0.037 sec)
# Epoch: 1648 Iteration: 40 : Loss: 0.2181 (0.036 sec)
# Epoch: 1648 Iteration: 43 : Loss: 0.2134 (0.036 sec)
# Epoch: 1648 Iteration: 46 : Loss: 0.2018 (0.037 sec)
# Epoch: 1648 Iteration: 49 : Loss: 0.2164 (0.036 sec)
# Epoch: 1648 Iteration: 52 : Loss: 0.2023 (0.036 sec)
# Epoch: 1648 Iteration: 55 : Loss: 0.2070 (0.044 sec)
# Epoch: 1648 Iteration: 58 : Loss: 0.1922 (0.037 sec)
# Epoch: 1649 Iteration: 2 : Loss: 0.2133 (0.036 sec)
# Epoch: 1649 Iteration: 5 : Loss: 0.2089 (0.036 sec)
# Epoch: 1649 Iteration: 8 : Loss: 0.2230 (0.036 sec)
# Epoch: 1649 Iteration: 11 : Loss: 0.2185 (0.036 sec)
# Epoch: 1649 Iteration: 14 : Loss: 0.2226 (0.036 sec)
# Epoch: 1649 Iteration: 17 : Loss: 0.2093 (0.036 sec)
# Epoch: 1649 Iteration: 20 : Loss: 0.2108 (0.035 sec)
# Epoch: 1649 Iteration: 23 : Loss: 0.2131 (0.036 sec)
# Epoch: 1649 Iteration: 26 : Loss: 0.2147 (0.035 sec)
# Epoch: 1649 Iteration: 29 : Loss: 0.2159 (0.036 sec)
# Epoch: 1649 Iteration: 32 : Loss: 0.2102 (0.036 sec)
# Epoch: 1649 Iteration: 35 : Loss: 0.2115 (0.038 sec)
# Epoch: 1649 Iteration: 38 : Loss: 0.2169 (0.036 sec)
# Epoch: 1649 Iteration: 41 : Loss: 0.2179 (0.036 sec)
# Epoch: 1649 Iteration: 44 : Loss: 0.2093 (0.036 sec)
# Epoch: 1649 Iteration: 47 : Loss: 0.2092 (0.036 sec)
# Epoch: 1649 Iteration: 50 : Loss: 0.2260 (0.036 sec)
# Epoch: 1649 Iteration: 53 : Loss: 0.2159 (0.036 sec)
# Epoch: 1649 Iteration: 56 : Loss: 0.2245 (0.036 sec)
# Epoch: 1649 Iteration: 59 : Loss: 0.2141 (0.045 sec)
# Epoch: 1650 Iteration: 3 : Loss: 0.2065 (0.036 sec)
# Epoch: 1650 Iteration: 6 : Loss: 0.1933 (0.036 sec)
# Epoch: 1650 Iteration: 9 : Loss: 0.2211 (0.037 sec)
# Epoch: 1650 Iteration: 12 : Loss: 0.2180 (0.036 sec)
# Epoch: 1650 Iteration: 15 : Loss: 0.2118 (0.036 sec)
# Epoch: 1650 Iteration: 18 : Loss: 0.2075 (0.040 sec)
# Epoch: 1650 Iteration: 21 : Loss: 0.2103 (0.036 sec)
# Epoch: 1650 Iteration: 24 : Loss: 0.2059 (0.036 sec)
# Epoch: 1650 Iteration: 27 : Loss: 0.1942 (0.036 sec)
# Epoch: 1650 Iteration: 30 : Loss: 0.2069 (0.035 sec)
# Epoch: 1650 Iteration: 33 : Loss: 0.2153 (0.036 sec)
# Epoch: 1650 Iteration: 36 : Loss: 0.1982 (0.036 sec)
# Epoch: 1650 Iteration: 39 : Loss: 0.2224 (0.037 sec)
# Epoch: 1650 Iteration: 42 : Loss: 0.2084 (0.036 sec)
# Epoch: 1650 Iteration: 45 : Loss: 0.2097 (0.036 sec)
# Epoch: 1650 Iteration: 48 : Loss: 0.2091 (0.036 sec)
# Epoch: 1650 Iteration: 51 : Loss: 0.2101 (0.036 sec)
# Epoch: 1650 Iteration: 54 : Loss: 0.2176 (0.036 sec)
# Epoch: 1650 Iteration: 57 : Loss: 0.2171 (0.036 sec)
# Epoch: 1651 Iteration: 1 : Loss: 0.2175 (0.044 sec)
# Epoch: 1651 Iteration: 4 : Loss: 0.2031 (0.036 sec)
# Epoch: 1651 Iteration: 7 : Loss: 0.2055 (0.036 sec)
# Epoch: 1651 Iteration: 10 : Loss: 0.2254 (0.036 sec)
# Epoch: 1651 Iteration: 13 : Loss: 0.2158 (0.042 sec)
# Epoch: 1651 Iteration: 16 : Loss: 0.2074 (0.036 sec)
# Epoch: 1651 Iteration: 19 : Loss: 0.2058 (0.042 sec)
# Epoch: 1651 Iteration: 22 : Loss: 0.2013 (0.036 sec)
# Epoch: 1651 Iteration: 25 : Loss: 0.2145 (0.036 sec)
# Epoch: 1651 Iteration: 28 : Loss: 0.2170 (0.036 sec)
# Epoch: 1651 Iteration: 31 : Loss: 0.2168 (0.037 sec)
# Epoch: 1651 Iteration: 34 : Loss: 0.2217 (0.036 sec)
# Epoch: 1651 Iteration: 37 : Loss: 0.2182 (0.036 sec)
# Epoch: 1651 Iteration: 40 : Loss: 0.2155 (0.035 sec)
# Epoch: 1651 Iteration: 43 : Loss: 0.2086 (0.037 sec)
# Epoch: 1651 Iteration: 46 : Loss: 0.2080 (0.035 sec)
# Epoch: 1651 Iteration: 49 : Loss: 0.2163 (0.036 sec)
# Epoch: 1651 Iteration: 52 : Loss: 0.2117 (0.037 sec)
# Epoch: 1651 Iteration: 55 : Loss: 0.2279 (0.037 sec)
# Epoch: 1651 Iteration: 58 : Loss: 0.2231 (0.045 sec)
# Epoch: 1652 Iteration: 2 : Loss: 0.1966 (0.037 sec)
# Epoch: 1652 Iteration: 5 : Loss: 0.2219 (0.035 sec)
# Epoch: 1652 Iteration: 8 : Loss: 0.2164 (0.036 sec)
# Epoch: 1652 Iteration: 11 : Loss: 0.2190 (0.036 sec)
# Epoch: 1652 Iteration: 14 : Loss: 0.2259 (0.044 sec)
# Epoch: 1652 Iteration: 17 : Loss: 0.2255 (0.036 sec)
# Epoch: 1652 Iteration: 20 : Loss: 0.2199 (0.041 sec)
# Epoch: 1652 Iteration: 23 : Loss: 0.2114 (0.036 sec)
# Epoch: 1652 Iteration: 26 : Loss: 0.2032 (0.035 sec)
# Epoch: 1652 Iteration: 29 : Loss: 0.2253 (0.036 sec)
# Epoch: 1652 Iteration: 32 : Loss: 0.1936 (0.036 sec)
# Saving at epoch 1652 step: 32
# Epoch: 1652 Iteration: 35 : Loss: 0.2123 (0.036 sec)
# Epoch: 1652 Iteration: 38 : Loss: 0.1931 (0.036 sec)
# Epoch: 1652 Iteration: 41 : Loss: 0.2465 (0.036 sec)
# Epoch: 1652 Iteration: 44 : Loss: 0.2105 (0.038 sec)
# Epoch: 1652 Iteration: 47 : Loss: 0.2029 (0.037 sec)
# Epoch: 1652 Iteration: 50 : Loss: 0.2017 (0.036 sec)
# Epoch: 1652 Iteration: 53 : Loss: 0.2129 (0.036 sec)
# Epoch: 1652 Iteration: 56 : Loss: 0.2206 (0.037 sec)
# Epoch: 1652 Iteration: 59 : Loss: 0.2139 (0.041 sec)
# Epoch: 1653 Iteration: 3 : Loss: 0.2047 (0.036 sec)
# Epoch: 1653 Iteration: 6 : Loss: 0.2155 (0.036 sec)
# Epoch: 1653 Iteration: 9 : Loss: 0.2086 (0.037 sec)
# Epoch: 1653 Iteration: 12 : Loss: 0.2183 (0.036 sec)
# Epoch: 1653 Iteration: 15 : Loss: 0.2167 (0.040 sec)
# Epoch: 1653 Iteration: 18 : Loss: 0.2144 (0.035 sec)
# Epoch: 1653 Iteration: 21 : Loss: 0.2097 (0.037 sec)
# Epoch: 1653 Iteration: 24 : Loss: 0.2088 (0.037 sec)
# Epoch: 1653 Iteration: 27 : Loss: 0.2200 (0.037 sec)
# Epoch: 1653 Iteration: 30 : Loss: 0.2217 (0.036 sec)
# Epoch: 1653 Iteration: 33 : Loss: 0.2145 (0.035 sec)
# Epoch: 1653 Iteration: 36 : Loss: 0.2285 (0.036 sec)
# Epoch: 1653 Iteration: 39 : Loss: 0.2082 (0.036 sec)
# Epoch: 1653 Iteration: 42 : Loss: 0.2075 (0.036 sec)
# Epoch: 1653 Iteration: 45 : Loss: 0.2024 (0.036 sec)
# Epoch: 1653 Iteration: 48 : Loss: 0.2065 (0.036 sec)
# Epoch: 1653 Iteration: 51 : Loss: 0.2214 (0.036 sec)
# Epoch: 1653 Iteration: 54 : Loss: 0.2258 (0.036 sec)
# Epoch: 1653 Iteration: 57 : Loss: 0.2099 (0.035 sec)
# Epoch: 1654 Iteration: 1 : Loss: 0.2191 (0.036 sec)
# Epoch: 1654 Iteration: 4 : Loss: 0.2035 (0.036 sec)
# Epoch: 1654 Iteration: 7 : Loss: 0.2210 (0.035 sec)
# Epoch: 1654 Iteration: 10 : Loss: 0.1965 (0.036 sec)
# Epoch: 1654 Iteration: 13 : Loss: 0.2008 (0.036 sec)
# Epoch: 1654 Iteration: 16 : Loss: 0.2040 (0.036 sec)
# Epoch: 1654 Iteration: 19 : Loss: 0.2036 (0.038 sec)
# Epoch: 1654 Iteration: 22 : Loss: 0.2188 (0.036 sec)
# Epoch: 1654 Iteration: 25 : Loss: 0.2275 (0.036 sec)
# Epoch: 1654 Iteration: 28 : Loss: 0.2126 (0.036 sec)
# Epoch: 1654 Iteration: 31 : Loss: 0.2091 (0.036 sec)
# Epoch: 1654 Iteration: 34 : Loss: 0.1971 (0.036 sec)
# Epoch: 1654 Iteration: 37 : Loss: 0.2008 (0.036 sec)
# Epoch: 1654 Iteration: 40 : Loss: 0.2047 (0.037 sec)
# Epoch: 1654 Iteration: 43 : Loss: 0.2287 (0.037 sec)
# Epoch: 1654 Iteration: 46 : Loss: 0.2131 (0.036 sec)
# Epoch: 1654 Iteration: 49 : Loss: 0.2291 (0.037 sec)
# Epoch: 1654 Iteration: 52 : Loss: 0.2143 (0.037 sec)
# Epoch: 1654 Iteration: 55 : Loss: 0.2087 (0.036 sec)
# Epoch: 1654 Iteration: 58 : Loss: 0.2000 (0.037 sec)
# Epoch: 1655 Iteration: 2 : Loss: 0.2318 (0.036 sec)
# Epoch: 1655 Iteration: 5 : Loss: 0.2221 (0.036 sec)
# Epoch: 1655 Iteration: 8 : Loss: 0.2352 (0.036 sec)
# Epoch: 1655 Iteration: 11 : Loss: 0.2332 (0.037 sec)
# Epoch: 1655 Iteration: 14 : Loss: 0.2164 (0.036 sec)
# Epoch: 1655 Iteration: 17 : Loss: 0.2137 (0.036 sec)
# Epoch: 1655 Iteration: 20 : Loss: 0.2131 (0.036 sec)
# Epoch: 1655 Iteration: 23 : Loss: 0.2091 (0.035 sec)
# Epoch: 1655 Iteration: 26 : Loss: 0.2037 (0.036 sec)
# Epoch: 1655 Iteration: 29 : Loss: 0.2210 (0.036 sec)
# Epoch: 1655 Iteration: 32 : Loss: 0.2091 (0.039 sec)
# Epoch: 1655 Iteration: 35 : Loss: 0.2009 (0.035 sec)
# Epoch: 1655 Iteration: 38 : Loss: 0.2303 (0.041 sec)
# Epoch: 1655 Iteration: 41 : Loss: 0.2147 (0.036 sec)
# Epoch: 1655 Iteration: 44 : Loss: 0.2093 (0.035 sec)
# Epoch: 1655 Iteration: 47 : Loss: 0.2249 (0.036 sec)
# Epoch: 1655 Iteration: 50 : Loss: 0.2080 (0.036 sec)
# Epoch: 1655 Iteration: 53 : Loss: 0.1985 (0.036 sec)
# Epoch: 1655 Iteration: 56 : Loss: 0.2166 (0.038 sec)
# Epoch: 1655 Iteration: 59 : Loss: 0.2221 (0.036 sec)
# Epoch: 1656 Iteration: 3 : Loss: 0.2014 (0.036 sec)
# Epoch: 1656 Iteration: 6 : Loss: 0.2157 (0.037 sec)
# Epoch: 1656 Iteration: 9 : Loss: 0.2170 (0.036 sec)
# Epoch: 1656 Iteration: 12 : Loss: 0.2137 (0.036 sec)
# Epoch: 1656 Iteration: 15 : Loss: 0.2039 (0.036 sec)
# Epoch: 1656 Iteration: 18 : Loss: 0.2023 (0.037 sec)
# Epoch: 1656 Iteration: 21 : Loss: 0.2202 (0.036 sec)
# Epoch: 1656 Iteration: 24 : Loss: 0.2123 (0.035 sec)
# Epoch: 1656 Iteration: 27 : Loss: 0.2001 (0.036 sec)
# Epoch: 1656 Iteration: 30 : Loss: 0.2157 (0.036 sec)
# Epoch: 1656 Iteration: 33 : Loss: 0.2109 (0.036 sec)
# Epoch: 1656 Iteration: 36 : Loss: 0.2100 (0.036 sec)
# Epoch: 1656 Iteration: 39 : Loss: 0.1989 (0.036 sec)
# Epoch: 1656 Iteration: 42 : Loss: 0.2102 (0.036 sec)
# Epoch: 1656 Iteration: 45 : Loss: 0.2150 (0.036 sec)
# Saving at epoch 1656 step: 46
# Epoch: 1656 Iteration: 48 : Loss: 0.2114 (0.036 sec)
# Epoch: 1656 Iteration: 51 : Loss: 0.2200 (0.036 sec)
# Epoch: 1656 Iteration: 54 : Loss: 0.2042 (0.036 sec)
# Epoch: 1656 Iteration: 57 : Loss: 0.2355 (0.036 sec)
# Epoch: 1657 Iteration: 1 : Loss: 0.1930 (0.036 sec)
# Epoch: 1657 Iteration: 4 : Loss: 0.1999 (0.036 sec)
# Epoch: 1657 Iteration: 7 : Loss: 0.2203 (0.037 sec)
# Epoch: 1657 Iteration: 10 : Loss: 0.2223 (0.036 sec)
# Epoch: 1657 Iteration: 13 : Loss: 0.2197 (0.036 sec)
# Epoch: 1657 Iteration: 16 : Loss: 0.2214 (0.036 sec)
# Epoch: 1657 Iteration: 19 : Loss: 0.2166 (0.037 sec)
# Epoch: 1657 Iteration: 22 : Loss: 0.2144 (0.036 sec)
# Epoch: 1657 Iteration: 25 : Loss: 0.2213 (0.036 sec)
# Epoch: 1657 Iteration: 28 : Loss: 0.2242 (0.038 sec)
# Epoch: 1657 Iteration: 31 : Loss: 0.1960 (0.044 sec)
# Epoch: 1657 Iteration: 34 : Loss: 0.2103 (0.038 sec)
# Epoch: 1657 Iteration: 37 : Loss: 0.2256 (0.039 sec)
# Epoch: 1657 Iteration: 40 : Loss: 0.2205 (0.039 sec)
# Epoch: 1657 Iteration: 43 : Loss: 0.2136 (0.051 sec)
# Epoch: 1657 Iteration: 46 : Loss: 0.2137 (0.037 sec)
# Epoch: 1657 Iteration: 49 : Loss: 0.1981 (0.038 sec)
# Epoch: 1657 Iteration: 52 : Loss: 0.2159 (0.049 sec)
# Epoch: 1657 Iteration: 55 : Loss: 0.2145 (0.057 sec)
# Epoch: 1657 Iteration: 58 : Loss: 0.2109 (0.052 sec)
# Epoch: 1658 Iteration: 2 : Loss: 0.1987 (0.045 sec)
# Epoch: 1658 Iteration: 5 : Loss: 0.2140 (0.051 sec)
# Epoch: 1658 Iteration: 8 : Loss: 0.2117 (0.045 sec)
# Epoch: 1658 Iteration: 11 : Loss: 0.2047 (0.048 sec)
# Epoch: 1658 Iteration: 14 : Loss: 0.2190 (0.050 sec)
# Epoch: 1658 Iteration: 17 : Loss: 0.2055 (0.047 sec)
# Epoch: 1658 Iteration: 20 : Loss: 0.2225 (0.041 sec)
# Epoch: 1658 Iteration: 23 : Loss: 0.2219 (0.055 sec)
# Epoch: 1658 Iteration: 26 : Loss: 0.2178 (0.037 sec)
# Epoch: 1658 Iteration: 29 : Loss: 0.2266 (0.037 sec)
# Epoch: 1658 Iteration: 32 : Loss: 0.2126 (0.052 sec)
# Epoch: 1658 Iteration: 35 : Loss: 0.2179 (0.050 sec)
# Epoch: 1658 Iteration: 38 : Loss: 0.2157 (0.048 sec)
# Epoch: 1658 Iteration: 41 : Loss: 0.2129 (0.052 sec)
# Epoch: 1658 Iteration: 44 : Loss: 0.2178 (0.050 sec)
# Epoch: 1658 Iteration: 47 : Loss: 0.2005 (0.037 sec)
# Epoch: 1658 Iteration: 50 : Loss: 0.2096 (0.038 sec)
# Epoch: 1658 Iteration: 53 : Loss: 0.2295 (0.038 sec)
# Epoch: 1658 Iteration: 56 : Loss: 0.2042 (0.062 sec)
# Epoch: 1658 Iteration: 59 : Loss: 0.2104 (0.065 sec)
# Epoch: 1659 Iteration: 3 : Loss: 0.2257 (0.037 sec)
# Epoch: 1659 Iteration: 6 : Loss: 0.2021 (0.037 sec)
# Epoch: 1659 Iteration: 9 : Loss: 0.2231 (0.041 sec)
# Epoch: 1659 Iteration: 12 : Loss: 0.2118 (0.044 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-519c916a434c> in <module>()
#      29         x_train, y_train = tf_utils.unison_shuffled_copies(x_train, y_train)
#      30
# ---> 31         for step, feed_dict in enumerate(input_fn()):
#      32             global_step += 1
#      33             start_time = time.time()
#
# <ipython-input-17-aa9ee33bf575> in input_fn()
#       7     for batch_input, batch_labels in tf_utils.generate_batch(
#       8         batch_size, number_of_batches, max_document_length,
# ----> 9                                                     x_train, y_train):
#      10         yield {input_data: batch_input, input_target: batch_labels}
#      11
#
# /home/max/textanalytics/tf_utils.py in generate_batch(batch_size, number_of_batches, max_document_length, input_data, input_labels)
#      67       # Prevents overflow.
#      68       data_index = ((batch_index * batch_size) + element_index) % input_data.shape[0]
# ---> 69       batch[element_index] = input_data.getrow(data_index).toarray()
#      70       labels[element_index] = input_labels[data_index]
#      71     batch_index += 1
#
# /usr/local/lib/python3.5/dist-packages/scipy/sparse/compressed.py in toarray(self, order, out)
#     918     def toarray(self, order=None, out=None):
#     919         """See the docstring for `spmatrix.toarray`."""
# --> 920         return self.tocoo(copy=False).toarray(order=order, out=out)
#     921
#     922     ##############################################################
#
# /usr/local/lib/python3.5/dist-packages/scipy/sparse/compressed.py in tocoo(self, copy)
#     906         major_dim, minor_dim = self._swap(self.shape)
#     907         minor_indices = self.indices
# --> 908         major_indices = np.empty(len(minor_indices), dtype=self.indices.dtype)
#     909         _sparsetools.expandptr(major_dim, self.indptr, major_indices)
#     910         row, col = self._swap((major_indices, minor_indices))
#
# KeyboardInterrupt:

# %%
# Model Evaluation
# number_of_validation_batches is used above in the eval_input_fn
number_of_validation_batches = math.floor(len(x_test_text)/batch_size)
# Load checkpointed model.
ckpt = tf.train.get_checkpoint_state(logs_dir)                                     

# Write TF Model Evaluation Code here. 
with tf.Session(graph=graph, config=tf.ConfigProto(
    allow_soft_placement=True, log_device_placement=True)) as session:
    
    saver = tf.train.Saver(tf.global_variables()) 
                                                                                                  
    session.run(tf.global_variables_initializer())
    
    saver.restore(session, ckpt.model_checkpoint_path)
    prediction_array_list = []

    total_loss = 0
    for step, eval_feed_dict in enumerate(eval_input_fn()):    
        valid_loss, mae, model_predictions = session.run(
            [loss, mean_absolute_error_salary_scale, model_output], feed_dict=eval_feed_dict)
        #print("Batch: %d Mean: %.4f" % (step, mae))
        total_loss += mae
        prediction_array_list.append(model_predictions)
    print ("Mean Absolute Error Loss over all %s observations = %s" % ((step + 1) * batch_size, total_loss / (step + 1)))
# Out:
# INFO:tensorflow:Restoring parameters from logs/neuralnetbagofwords/2017-06-28-21-25-42-5750
# Mean Absolute Error Loss over all 51200 observations = 6890.73701172

# %%
def flatten_predictions(predictions):
    return numpy.concatenate(predictions)

predictions = flatten_predictions(prediction_array_list)

n_predictions = predictions.shape[0]

actuals = y_test[0:n_predictions]

print(n_predictions, actuals.shape)
print(y_test)
# Out:
# 51200 (51200,)
# [ 0.89645004 -0.66550416  3.22435188 ..., -0.29010177  0.89645004
#   0.95295256]

# %%
# %matplotlib inline

def print_results(x_vals, y_vals):

    plt.scatter(x_vals, y_vals, alpha=.1)
    plt.show()

    print(x_vals-y_vals)
    #print(sorted([set(y_vals)]))

print_results(actuals, predictions)
# Out:
# [[-1.2662046  -2.82815886  1.06169724 ...,  0.65487933 -2.19849539
#   -2.53751016]
#  [ 2.22026563  0.65831143  4.54816723 ...,  4.14134979  1.28797495
#    0.94896007]
#  [-4.18580246 -5.74775648 -1.85790062 ..., -2.26471853 -5.11809301
#   -5.45710802]
#  ...,
#  [-1.50738144 -3.0693357   0.8205204  ...,  0.41370249 -2.43967223
#   -2.778687  ]
#  [ 0.8513     -0.7106542   3.17920184 ...,  2.77238393 -0.0809907
#   -0.42000553]
#  [ 1.43651092 -0.12544328  3.76441288 ...,  3.35759497  0.50422019
#    0.16520539]]
